# %%
import random

# %%
def get_sentences(word_of_interest, min_words, max_words):
    """
    """
    # Cleaned data files.
    directory = '/raid/antoloui/Master-thesis/_data/cleaned/'
    files = ['train.raw', 'dev.raw', 'test.raw']
    paths = [directory+f for f in files]
    
    # Get sentences with word of interest in it.
    sentences = []
    for filepath in paths:
        with open(filepath) as myfile:
            for i, line in enumerate(myfile):
                words = line.split()
                if len(words) > min_words and len(words) < max_words and word_of_interest in words:
                    sentences.append(line)
    return sentences

# %%
sentences = get_sentences(word_of_interest="switch", min_words=5, max_words=20)

# %%
samples = random.sample(sentences, 100)
for sample in samples:
    print(sample)
# Out:
# Blade Subprofile This subprofile describes how blades in a director class switch can be discovered and managed.
#
# Because the switch acts as the proxy, the authentication service is transparent to the client.
#
# It is recommended to enable power policing if the switch supports it.
#
# Mitigation options for this type of attack can be handled at the switch level.
#
# The switch responds to DHCP requests only if it is configured as a DHCP server.
#
# When enabled, TACACS+ can authenticate users accessing the switch through the CLI.
#
# This statement also applies if the stack master is removed from the switch stack.
#
# Assigning Switch Information You can assign IP information through the switch setup program, through a DHCP server, or manually.
#
# Note Static connections to multicast routers are supported only on switch ports.
#
# switch Sets the role of the attached device to switch.
#
# Note If you omit the optional interface keyword, all interfaces on the switch are tested.
#
# ...
