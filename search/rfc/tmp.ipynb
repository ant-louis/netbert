# %%
import os
import re
import string


def read_file(dirpath, filename):
    """
    Read the RFC text file and return corresponding lines.
    """
    with open(os.path.join(dirpath, filename), 'r') as f:
        lines = [line.rstrip() for line in f]
    return lines


def process_lines(lines, title, date):
    """
    Given the lines from the raw RFC document, concat the lines 
    forming the same paragraph.
    """
    # Remove all empty lines.
    #lines = [line for line in lines if line]
    
    # Remove all "head" lines in above each page.
    lines = [line for line in lines if not bool(re.search("\[Page.*\]", line))]
    lines = [line for line in lines if not bool(re.search("RFC.*" + date, line))]
    
    # Remove lines with too many special characters.
    lines = [line for line in lines if len(re.sub('[A-Za-z0-9\s]+', '', line))/max(len(line) - line.count(' '), 1) < 0.3]
    
    # Remove lines with too many spaces.
    lines = [line for line in lines if line.count(' ')/max(len(line), 1) < 0.5]
    
    # Remove xml lines.
    r = re.compile('[\s]+<.*?>[\s]+')
    lines = [line for line in lines if r.match(line) is None]
    
    return lines
    
    # Create paragraphs from lines.
    new_lines = []
    section_name = ''
    while lines:

        # Pop the current line.
        line = lines.pop(0)
        
        # If line is empty, skip it.
        if not line: continue

        # Get the number of whitespaces at the beginning of the line.
        line_whitespaces = len(line) - len(line.lstrip(' '))

        # If there are no whitespaces at the beginning of current line...
        if line_whitespaces == 0:
            # Then, the current line is the name of a section.
            section_name = line + '. '  # store this name.
        else:
            # Otherwise, the current line is a line from a paragraph in that section.
            paragraph = section_name + line # append the section name at the start of the paragraph.

            counter_whitespaces = line_whitespaces  # get the current indentation.
            while (
                    lines and                                                             # while there are still lines to read
                    len(lines[0]) - len(lines[0].lstrip(' ')) == counter_whitespaces      # and the next line has the same indentation than previous one
                  ):
                paragraph += lines.pop(0)  # add new line to paragraph.

            new_lines.append(paragraph)
            
    # Remove all multiple spaces.
    new_lines = [re.sub('\s{2,}', ' ', line) for line in new_lines]
    
    # If line begins with a number, remove it.
    new_lines = [line.split(maxsplit=1)[1] if (len(line.split(maxsplit=1))>1 and line.split(maxsplit=1)[0][0].isdigit()) else line for line in new_lines]
    
    # Remove lines from Table of contents.
    new_lines = [line for line in new_lines if not line.startswith("Table of Contents.")]
    
    # Add title of RFC to beginning of each chunk.
    new_lines = [title + ' - ' + line for line in new_lines]
    
    return new_lines

# %%
dirpath = '/raid/antoloui/Master-thesis/_data/search/rfc/raw_files'
filename = 'rfc5707.txt'
title = "Media Server Markup Language (MSML)"
date = 'February 2010'

lines = read_file(dirpath, filename)
lines = process_lines(lines, title, date)
#lines

# %%
lines = lines[:100]
for line in lines: print(line)
# Out:
#                   Media Server Markup Language (MSML)
#
# Abstract
#
#    The Media Server Markup Language (MSML) is used to control and invoke
#    many different types of services on IP media servers.  The MSML
#    control interface was initially driven by RadiSys with subsequent
#    significant contributions from Intel, Dialogic, and others in the
#    industry.  Clients can use it to define how multimedia sessions
#    interact on a media server and to apply services to individuals or
#    groups of users.  MSML can be used, for example, to control media
#    server conferencing features such as video layout and audio mixing,
#    create sidebar conferences or personal mixes, and set the properties
#    of media streams.  As well, clients can use MSML to define media
#    processing dialogs, which may be used as parts of application
#    interactions with users or conferences.  Transformation of media
#    streams to and from users or conferences as well as interactive voice
#    response (IVR) dialogs are examples of such interactions, which are
#    specified using MSML.  MSML clients may also invoke dialogs with
#    individual users or with groups of conference participants using
#    VoiceXML.
#
# Status of This Memo
#
#    This document is not an Internet Standards Track specification; it is
#    published for informational purposes.
#
#    This is a contribution to the RFC Series, independently of any other
#    RFC stream.  The RFC Editor has chosen to publish this document at
#    its discretion and makes no statement about its value for
#    implementation or deployment.  Documents approved for publication by
#    the RFC Editor are not a candidate for any level of Internet
#    Standard; see Section 2 of RFC 5741.
#
#    Information about the current status of this document, any errata,
#    and how to provide feedback on it may be obtained at
#    http://www.rfc-editor.org/info/rfc5707.
#
#
#
#
#
#
#
#
#
# IESG Note
#
#    This RFC is not a candidate for any level of Internet Standard.  The
#    IETF disclaims any knowledge of the fitness of this RFC for any
#    purpose and in particular notes that the decision to publish is not
#    based on IETF review for such things as security, congestion control,
#    or inappropriate interaction with deployed protocols.  The RFC Editor
#    has chosen to publish this document at its discretion.  Readers of
#    this document should exercise caution in evaluating its value for
#    implementation and deployment.  See RFC 3932 for more information.
#
# Copyright Notice
#
#    Copyright (c) 2010 IETF Trust and the persons identified as the
#    document authors.  All rights reserved.
#
#    This document is subject to BCP 78 and the IETF Trust's Legal
#    Provisions Relating to IETF Documents
#    (http://trustee.ietf.org/license-info) in effect on the date of
#    publication of this document.  Please review these documents
#    carefully, as they describe your rights and restrictions with respect
#    to this document.
#
# Table of Contents
#
#
#
#
#
#
#
#
#
#
#
#
#
#       18.1. IANA Registrations for 'application' MIME Media Type ....176
#       18.2. IANA Registrations for 'text' MIME Media Type ...........178
#
# 1.  Introduction
#
#    Media servers contain dynamic pools of media resources.  Control
#    agents and other users of media servers (called media server clients)
#    can define and create many different services based on how they
#    configure and use those resources.  Often, that configuration and the

# %%
# Create paragraphs from lines.
new_lines = []
section_name = []
section_whitespaces = -1
section_whitespaces = [0]
chunk = ''

while lines:

    # Pop the current line.
    line = lines.pop(0)
    print("\nLine: {}".format(line))
    
    # If line is empty, skip it.
    if not line: continue

    # Get the number of whitespaces at the beginning of the line.
    line_whitespaces = len(line) - len(line.lstrip(' '))
    print("Whitespaces: {}".format(line_whitespaces))

    # If the number of whitespaces at the beginning of the current line is bigger than the up-to-date number of whitespaces of the current (sub)section...
    if line_whitespaces > section_whitespaces:
        # It means that the previous chunk was a subsection.
        section_name.append(chunk)  # append previous chunk as a subsection to the current section names list.
        section_whitespaces = line_whitespaces  # update the number of whitespaces for the current subsection.
        print("Current line has more whitespaces.")
        print("Sections: {}".format(str(section_name)))
        print("Updated whitespaces: {}".format(section_whitespaces))
    
    # If the number of whitespaces at the beginning of the current line is exactly equal to the up-to-date number of whitespaces of the current (sub)section...
    elif line_whitespaces == section_whitespaces:
        # It means that the previous chunk was not a new subsection but well a paragraph of the current section.
        paragraph = ' - '.join(section_name) + '. ' + chunk  # create new paragraph as the concatenation of the section and subsections names + the previous chunk.
        new_lines.append(paragraph)  # append it to new_lines.
        print("Current line has same number whitespaces.")
        print("Appending previous chunk: {}".format(paragraph))
    
    # If the number of whitespaces at the beginning of the current line is lower than the up-to-date number of whitespaces of the current (sub)section...
    else:
        # It means that we moved out of the current subsection.
        paragraph = ' - '.join(section_name) + '. ' + chunk  # create new paragraph as the concatenation of the section and subsections names + the previous chunk.
        new_lines.append(paragraph)  # append it to new_lines.
        section_name.pop(-1)  # remove the last encountered subsection from the section names list.
        section_whitespaces = line_whitespaces  # update the number of whitespaces for the current subsection.
        print("Current line has less whitespaces.")
        print("Appending previous chunk: {}".format(paragraph))
        print("Updated sections: {}".format(section_name))
        print("Updated whitespaces: {}".format(section_whitespaces))
        
    # Get the next chunk.
    chunk = line
    while lines and lines[0]:
        chunk += lines.pop(0)  # add new line to paragraph.
       
# Remove all multiple spaces.
new_lines = [re.sub('\s{2,}', ' ', line) for line in new_lines]

# If line begins with a number, remove it.
new_lines = [line.split(maxsplit=1)[1] if (len(line.split(maxsplit=1))>1 and line.split(maxsplit=1)[0][0].isdigit()) else line for line in new_lines]

# Remove lines from Table of contents.
new_lines = [line for line in new_lines if not line.startswith("Table of Contents.")]
# Out:
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:                   Media Server Markup Language (MSML)
# Whitespaces: 18
# Current line has more whitespaces.
# Sections: ['']
# Updated whitespaces: 18
#
# Line:
#
# Line: Abstract
# Whitespaces: 0
# Current line has less whitespaces.
# Appending previous chunk: .                   Media Server Markup Language (MSML)
# Updated sections: []
# Updated whitespaces: 0
#
# Line:
#
# Line:    The Media Server Markup Language (MSML) is used to control and invoke
# Whitespaces: 3
# Current line has more whitespaces.
# Sections: ['Abstract']
# Updated whitespaces: 3
#
# Line:
#
# Line: Status of This Memo
# Whitespaces: 0
# Current line has less whitespaces.
# Appending previous chunk: Abstract.    The Media Server Markup Language (MSML) is used to control and invoke   many different types of services on IP media servers.  The MSML   control interface was initially driven by RadiSys with subsequent   significant contributions from Intel, Dialogic, and others in the   industry.  Clients can use it to define how multimedia sessions   interact on a media server and to apply services to individuals or   groups of users.  MSML can be used, for example, to control media   server conferencing features such as video layout and audio mixing,   create sidebar conferences or personal mixes, and set the properties   of media streams.  As well, clients can use MSML to define media   processing dialogs, which may be used as parts of application   interactions with users or conferences.  Transformation of media   streams to and from users or conferences as well as interactive voice   response (IVR) dialogs are examples of such interactions, which are   specified using MSML.  MSML clients may also invoke dialogs with   individual users or with groups of conference participants using   VoiceXML.
# Updated sections: []
# Updated whitespaces: 0
#
# Line:
#
# Line:    This document is not an Internet Standards Track specification; it is
# Whitespaces: 3
# Current line has more whitespaces.
# Sections: ['Status of This Memo']
# Updated whitespaces: 3
#
# Line:
#
# Line:    This is a contribution to the RFC Series, independently of any other
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: Status of This Memo.    This document is not an Internet Standards Track specification; it is   published for informational purposes.
#
# Line:
#
# Line:    Information about the current status of this document, any errata,
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: Status of This Memo.    This is a contribution to the RFC Series, independently of any other   RFC stream.  The RFC Editor has chosen to publish this document at   its discretion and makes no statement about its value for   implementation or deployment.  Documents approved for publication by   the RFC Editor are not a candidate for any level of Internet   Standard; see Section 2 of RFC 5741.
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line: IESG Note
# Whitespaces: 0
# Current line has less whitespaces.
# Appending previous chunk: Status of This Memo.    Information about the current status of this document, any errata,   and how to provide feedback on it may be obtained at   http://www.rfc-editor.org/info/rfc5707.
# Updated sections: []
# Updated whitespaces: 0
#
# Line:
#
# Line:    This RFC is not a candidate for any level of Internet Standard.  The
# Whitespaces: 3
# Current line has more whitespaces.
# Sections: ['IESG Note']
# Updated whitespaces: 3
#
# Line:
#
# Line: Copyright Notice
# Whitespaces: 0
# Current line has less whitespaces.
# Appending previous chunk: IESG Note.    This RFC is not a candidate for any level of Internet Standard.  The   IETF disclaims any knowledge of the fitness of this RFC for any   purpose and in particular notes that the decision to publish is not   based on IETF review for such things as security, congestion control,   or inappropriate interaction with deployed protocols.  The RFC Editor   has chosen to publish this document at its discretion.  Readers of   this document should exercise caution in evaluating its value for   implementation and deployment.  See RFC 3932 for more information.
# Updated sections: []
# Updated whitespaces: 0
#
# Line:
#
# Line:    Copyright (c) 2010 IETF Trust and the persons identified as the
# Whitespaces: 3
# Current line has more whitespaces.
# Sections: ['Copyright Notice']
# Updated whitespaces: 3
#
# Line:
#
# Line:    This document is subject to BCP 78 and the IETF Trust's Legal
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: Copyright Notice.    Copyright (c) 2010 IETF Trust and the persons identified as the   document authors.  All rights reserved.
#
# Line:
#
# Line: Table of Contents
# Whitespaces: 0
# Current line has less whitespaces.
# Appending previous chunk: Copyright Notice.    This document is subject to BCP 78 and the IETF Trust's Legal   Provisions Relating to IETF Documents   (http://trustee.ietf.org/license-info) in effect on the date of   publication of this document.  Please review these documents   carefully, as they describe your rights and restrictions with respect   to this document.
# Updated sections: []
# Updated whitespaces: 0
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:       18.1. IANA Registrations for 'application' MIME Media Type ....176
# Whitespaces: 6
# Current line has more whitespaces.
# Sections: ['Table of Contents']
# Updated whitespaces: 6
#
# Line:
#
# Line: 1.  Introduction
# Whitespaces: 0
# Current line has less whitespaces.
# Appending previous chunk: Table of Contents.       18.1. IANA Registrations for 'application' MIME Media Type ....176      18.2. IANA Registrations for 'text' MIME Media Type ...........178
# Updated sections: []
# Updated whitespaces: 0
#
# Line:
#
# Line:    Media servers contain dynamic pools of media resources.  Control
# Whitespaces: 3
# Current line has more whitespaces.
# Sections: ['1.  Introduction']
# Updated whitespaces: 3
#
# Line:
#
# Line:    For example, a call may undergo an initial IVR dialog before being
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 1.  Introduction.    Media servers contain dynamic pools of media resources.  Control   agents and other users of media servers (called media server clients)   can define and create many different services based on how they   configure and use those resources.  Often, that configuration and the   ways in which those resources interact will be changed dynamically   over the course of a call, to reflect changes in the way that an   application interacts with a user.
#
# Line:
#
# Line:    The Media Server Markup Language (MSML) is an XML [n2] language used
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 1.  Introduction.    For example, a call may undergo an initial IVR dialog before being   placed into a conference.  Calls may be moved from a main conference   to a sidebar conference and then back again.  Individual calls may be   directly bridged to create small n-way calls or simple sidebars.   None of these change the SIP [n1] dialog or RTP [i3] session.  Yet   these do affect the media flow and processing internal to the media   server.
#
# Line:
#
# Line:    MSML may also be used to create user interaction dialogs and allows
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 1.  Introduction.    The Media Server Markup Language (MSML) is an XML [n2] language used   to control the flow of media streams and services applied to media   streams within a media server.  It is used to invoke many different   types of services on individual sessions, groups of sessions, and   conferences.  MSML allows the creation of conferences, bridging   different sessions together, and bridging sessions into conferences.
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:    MSML is a transport independent language, such that it does not rely
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 1.  Introduction.    MSML may also be used to create user interaction dialogs and allows   the application of media transforms to media streams.  Media   interaction dialogs created using MSML allow construction of IVR   dialog sessions to individual users as well as to groups of users   participating in a conference.  Dialogs may also be specified using   other languages, VoiceXML [n5], which support complete single-party   application logic to be executed on the media server.
#
# Line:
#
# Line:    A network connection may be established with the media server using
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 1.  Introduction.    MSML is a transport independent language, such that it does not rely   on underlying transport mechanisms and language semantics are   independent of transport.  However, SIP is a typical and commonly   used transport mechanism for MSML, invoked using the SIP URI scheme.   This specification defines using MSML dialogs using SIP as the   transport mechanism.
#
# Line:
#
# Line:    MSML has been designed to address the control and manipulation of
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 1.  Introduction.    A network connection may be established with the media server using   SIP.  Media received and transmitted on that connection will flow   through different media resources on the media server depending on   the requested service.  Basic Network Media Services with SIP [n7]   defines conventions for associating a basic service with a SIP   Request-URI.  MSML allows services to be dynamically applied and   changed by a control agent during the lifetime of the SIP dialog.
#
# Line:
#
# Line:    The MSML control interface has been widely deployed in the industry,
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 1.  Introduction.    MSML has been designed to address the control and manipulation of   media processing operations (e.g., announcement, IVR, play and   record, automatic speech recognition (ASR), text to speech (TTS),   fax, video), as well as control and relationships of media streams   (e.g., simple and advanced conferencing).  It provides a general-   purpose media server control architecture.  MSML can additionally be   used to invoke other more complex IVR languages such as VoiceXML.
#
# Line:
#
# Line: 2.  Glossary
# Whitespaces: 0
# Current line has less whitespaces.
# Appending previous chunk: 1.  Introduction.    The MSML control interface has been widely deployed in the industry,   with numerous client-side and server-side implementations, since   2003.  The in-service commercial deployments cover a wide variety of   applications including, but not limited to, IP multimedia   conferencing, network voice services, IVR, IVVR (interactive voice   and video response), and voice/video mail.
# Updated sections: []
# Updated whitespaces: 0
#
# Line:
#
# Line:    Media Server: a general-purpose platform for executing real-time
# Whitespaces: 3
# Current line has more whitespaces.
# Sections: ['2.  Glossary']
# Updated whitespaces: 3
#
# Line:
#
# Line:    Media Server Client: an application that originates MSML requests to
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 2.  Glossary.    Media Server: a general-purpose platform for executing real-time   media processing tasks.  This is a logical function that maps either   to a single physical device or to a portion of a physical device.
#
# Line:
#
# Line:    Network Connection: a participant that represents the termination on
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 2.  Glossary.    Media Server Client: an application that originates MSML requests to   a media server and also referred to as a control agent in this   specification.
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:    Dialog: an automated IVR participant.  Examples of dialogs may be
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 2.  Glossary.    Network Connection: a participant that represents the termination on   a media server of one or more RTP [i3] sessions (for example, audio   and video) associated with a call.  Network connections are   established and removed using a session establishment protocol such   as SIP.  An instance of a network connection is independent of MSML   processing instructions applied to it.
#
# Line:
#
# Line:    Conference: an intermediary function that provides multimedia mixing
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 2.  Glossary.    Dialog: an automated IVR participant.  Examples of dialogs may be   announcement players, IVR interfaces, or voice recorders.  Dialogs   may be defined in MSML or using VoiceXML [n5].
#
# Line:
#
# Line:    Identifier: a name that is used to refer to a specific instance of an
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 2.  Glossary.    Conference: an intermediary function that provides multimedia mixing   and other advanced conferencing services.  This specification   currently considers conferences with audio and/or video media types,   but is extensible to other media types.
#
# Line:
#
# Line:    Object: the generic term for a media server entity that terminates,
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 2.  Glossary.    Identifier: a name that is used to refer to a specific instance of an   object on the media server, such as a conference or a dialog.   Identifiers are composed of one or more terms where each term   identifies an object class and instance.
#
# Line:
#
# Line:    Participant Object: an object in a media server that sources original
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 2.  Glossary.    Object: the generic term for a media server entity that terminates,   originates, or processes media.  This specification defines four   classes of objects and specifies mechanisms to create them, join them   together, and destroy them.
#
# Line:
#
# Line:    Intermediary Object: an object in a media server that acts on media
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 2.  Glossary.    Participant Object: an object in a media server that sources original   media in a call and/or receives and terminates media in a call.
#
# Line:
#
# Line:    Independent Object: an object that can exist on a media server
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 2.  Glossary.    Intermediary Object: an object in a media server that acts on media   within a call for the benefit of the participants.
#
# Line:
#
# Line:    Operator: an intermediary transformer that modifies or transforms a
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 2.  Glossary.    Independent Object: an object that can exist on a media server   independent of other objects.
#
# Line:
#
# Line:    Media Stream: a single media flow between two objects.  A media
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 2.  Glossary.    Operator: an intermediary transformer that modifies or transforms a   media stream.  Examples of operators may be audio gain controls,   video scaling, or voice masking.  MSML defines operators as media   transform objects, which transform media using operations such as   gain control, when applied to media streams.
#
# Line:
#
# Line: 3.  MSML SIP Usage
# Whitespaces: 0
# Current line has less whitespaces.
# Appending previous chunk: 2.  Glossary.    Media Stream: a single media flow between two objects.  A media   stream has a media type and may be unidirectional or bidirectional.
# Updated sections: []
# Updated whitespaces: 0
#
# Line:
#
# Line:    SIP is used to create and modify media sessions with a media server
# Whitespaces: 3
# Current line has more whitespaces.
# Sections: ['3.  MSML SIP Usage']
# Updated whitespaces: 3
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:    MSML transactions are originated based upon events that occur in the
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 3.  MSML SIP Usage.    SIP is used to create and modify media sessions with a media server   according to the procedures defined in RFC 3261 [n1].  Often, SIP   third party call control [i4] will be used to create sessions to a   media server on behalf of end users.  MSML is used to define and   change the service that a user connected to a media server will   receive.  MSML clients are application servers, soft-switches, or   other forms of control agents, and SHOULD have an authorized security   relationship with the media server.  MSML itself does not define   authorization mechanisms.
#
# Line:
#
# Line:    MSML is purposely designed to be transport independent.  In this
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 3.  MSML SIP Usage.    MSML transactions are originated based upon events that occur in the   application domain.  These events may be independent from any media   or user interaction.  For example, an application may wish to play an   announcement to a conference warning that its scheduled completion   time is approaching.  Applications themselves are structured in many   different ways.  Their structure and requirements contribute to their   selection of protocols and languages.  To accommodate differing   application needs, MSML has been designed to be neutral to other   languages and independent of the transport used to carry it.
#
# Line:
#
# Line: 3.1.  SIP INFO
# Whitespaces: 0
# Current line has less whitespaces.
# Appending previous chunk: 3.  MSML SIP Usage.    MSML is purposely designed to be transport independent.  In this   release of the specification, SIP INFO [i5] and SIP Control Framework   [i11] have been chosen for transport mechanisms for MSML, as   described in the following sections.
# Updated sections: []
# Updated whitespaces: 0
#
# Line:
#
# Line:    SIP INVITE and INFO [i5] requests and responses MAY be used to carry
# Whitespaces: 3
# Current line has more whitespaces.
# Sections: ['3.1.  SIP INFO']
# Updated whitespaces: 3
#
# Line:
#
# Line:    Although INFO is sometimes considered not to be a suitable general-
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 3.1.  SIP INFO.    SIP INVITE and INFO [i5] requests and responses MAY be used to carry   MSML.  INFO requests allow asynchronous mid-call messages within SIP   with few additional semantics.  In addition, there are existing   widely deployed implementations of that method, it aids in initial   developments that are closely coupled with SIP session establishment,   and it allows MSML to be directly associated with user dialogs when   third party call control is used.
#
# Line:
#
# Line:    MSML supports several models for client interaction.  When clients
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 3.1.  SIP INFO.    Although INFO is sometimes considered not to be a suitable general-   purpose transport mechanism for messages within SIP, there have been   proposals to make it more acceptable.  MSML may evolve to include   other SIP usage and/or to work with other protocols or as a stand-   alone protocol established through SIP, in future releases of this   document.
#
# Line:
#
# Line:    An application, after interacting with a user, may want to affect
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 3.1.  SIP INFO.    MSML supports several models for client interaction.  When clients   use 3PCC to establish media sessions on behalf of end users, clients   will have a SIP dialog for each media session.  MSML MAY be sent on   these dialogs.  However the targets of MSML actions are not inferred   from the session associated with the SIP dialog.  The targets of MSML   actions are always explicitly specified using identifiers as   previously defined.
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:    MSML also supports a model of dedicated control associations.  This
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 3.1.  SIP INFO.    An application, after interacting with a user, may want to affect   multiple objects within a media server.  For example, tones or   messages are often played to a conference when connections are added   or removed.  A separate message may also be played to a participant   as they are joined, or to moderators.  Explicit identifiers, that is,   not inferred from a transport mechanism, allow these multiple actions   to be easily grouped into a single transaction sent on any SIP   dialog.
#
# Line:
#
# Line:    A media server using MSML also sends asynchronous events to a client
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 3.1.  SIP INFO.    MSML also supports a model of dedicated control associations.  This   supports decoupled application architectures where a client can   control media server services without also establishing all of the   media sessions itself.  Control associations are created using SIP,   but they do not have any associated media session.  Although   initially INFO messages will be sent on this SIP dialog, just as with   dialogs associated with media sessions, it is possible that in the   future, the SIP dialog will be used to establish a separate control   session (defined in SDP [n9]) that does not use SIP as the transport   for MSML messages.
#
# Line:
#
# Line:    Events may be generated during the execution of a dialog created by a
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 3.1.  SIP INFO.    A media server using MSML also sends asynchronous events to a client   using MSML scripts in SIP INFO.  Events are sent based on previous   MSML requests and are sent within the SIP dialog on which the MSML   request that caused the event to be generated was received.  If this   dialog no longer exists when the event is generated, the event is   discarded.
#
# Line:
#
# Line:    An event is also generated when the execution of a dialog terminates,
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 3.1.  SIP INFO.    Events may be generated during the execution of a dialog created by a   user input.  VoiceXML dialogs, on the other hand, generally interact   with other servers outside of MSML using HTTP.
#
# Line:
#
# Line:    Conferences may also generate events based upon their configuration.
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 3.1.  SIP INFO.    An event is also generated when the execution of a dialog terminates,   because of either completion or failure.  The exact information   returned is dependent on the dialog language, the capabilities of the   dialog execution environment, and what was requested by the dialog.   Both MSML and VoiceXML [n5] allow information to be returned when   they exit.  These events may be sent in a SIP INFO or a SIP BYE.  SIP   BYE is used when the dialog itself specifies that the connection   should be disconnected, for example, through the use of the
#
# Line:
#
# Line: 3.2.  SIP Control Framework
# Whitespaces: 0
# Current line has less whitespaces.
# Appending previous chunk: 3.1.  SIP INFO.    Conferences may also generate events based upon their configuration.   An example of this is the notification of the set of active speakers.
# Updated sections: []
# Updated whitespaces: 0
#
# Line:
#
# Line:    The SIP Control Framework [i11] MAY be used as a transport mechanism
# Whitespaces: 3
# Current line has more whitespaces.
# Sections: ['3.2.  SIP Control Framework']
# Updated whitespaces: 3
#
# Line:
#
# Line:    The Control Framework provides a generic approach for establishment
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 3.2.  SIP Control Framework.    The SIP Control Framework [i11] MAY be used as a transport mechanism   for MSML.
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:    SIP Control Framework is a more general-purpose transport mechanism
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 3.2.  SIP Control Framework.    The Control Framework provides a generic approach for establishment   and reporting capabilities of remotely initiated commands.  The   framework utilizes many functions provided by the Session Initiation   Protocol (SIP) [n1] for the rendezvous and establishment of a   reliable channel for control interactions.  Compared to SIP INFO, the
#
# Line:
#
# Line:    The Control Framework also introduces the concept of a Control
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 3.2.  SIP Control Framework.    SIP Control Framework is a more general-purpose transport mechanism   and one that is not constrained by limitations of the SIP INFO   mechanism.
#
# Line:
#
# Line:    This section fulfills the mandatory requirement for information that
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 3.2.  SIP Control Framework.    The Control Framework also introduces the concept of a Control   Package, which is an explicit usage of the Control Framework for a   particular interaction set.  This specification has already specified   a list of packages for MSML to control the media server in many   aspects, including basic dialog, advanced conferencing, advanced   dialog, and audit service.  Each of these packages has a unique   Control Package name assigned in order for MSML to be used with the   Control Framework.
#
# Line:
#
# Line: 3.2.1.  Control Framework Package Names
# Whitespaces: 0
# Current line has less whitespaces.
# Appending previous chunk: 3.2.  SIP Control Framework.    This section fulfills the mandatory requirement for information that   MUST be specified during the definition of a Control Framework   Package, as detailed in SIP Control Framework [i11].
# Updated sections: []
# Updated whitespaces: 0
#
# Line:
#
# Line:    The Control Framework [i11] requires a Control Package definition to
# Whitespaces: 3
# Current line has more whitespaces.
# Sections: ['3.2.1.  Control Framework Package Names']
# Updated whitespaces: 3
#
# Line:
#
# Line:    MSML specification defines Control Package names using a hierarchical
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 3.2.1.  Control Framework Package Names.    The Control Framework [i11] requires a Control Package definition to   specify and register a unique name.
#
# Line:
#
# Line:    The following is a list of Control Package names reserved by the MSML
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 3.2.1.  Control Framework Package Names.    MSML specification defines Control Package names using a hierarchical   scheme to indicate the inherited relationship across packages.  For   example, package "msml-x" is derived from package "msml", and package   "msml-x-y" is derived from package "msml-x".
#
# Line:
#
# Line:    "msml": this Control Package supports MSML Core Package as specified
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 3.2.1.  Control Framework Package Names.    The following is a list of Control Package names reserved by the MSML   specification.
#
# Line:
#
# Line:    "msml-conf": this Control Package supports MSML Conference Core
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 3.2.1.  Control Framework Package Names.    "msml": this Control Package supports MSML Core Package as specified      in section 7.
#
# Line:
#
# Line:    "msml-dialog": this Control Package supports MSML Dialog Core Package
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 3.2.1.  Control Framework Package Names.    "msml-conf": this Control Package supports MSML Conference Core      Package as specified in section 8.
#
# Line:
#
# Line:    "msml-dialog-base": this Control Package supports MSML Dialog Base
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 3.2.1.  Control Framework Package Names.    "msml-dialog": this Control Package supports MSML Dialog Core Package      as specified in section 9.6.
#
# Line:
#
# Line:    "msml-dialog-group": this Control Package supports MSML Dialog Group
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 3.2.1.  Control Framework Package Names.    "msml-dialog-base": this Control Package supports MSML Dialog Base      Package as specified in section 9.7.
#
# Line:
#
# Line:    "msml-dialog-transform": this Control Package supports MSML Dialog
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 3.2.1.  Control Framework Package Names.    "msml-dialog-group": this Control Package supports MSML Dialog Group      Package as specified in section 9.8.
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:    "msml-dialog-speech": this Control Package supports MSML Dialog
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 3.2.1.  Control Framework Package Names.    "msml-dialog-transform": this Control Package supports MSML Dialog      Transform Package as specified in section 9.9.
#
# Line:
#
# Line:    "msml-dialog-fax-detect": this Control Package supports MSML Dialog
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 3.2.1.  Control Framework Package Names.    "msml-dialog-speech": this Control Package supports MSML Dialog      Speech Package as specified in section 9.10.
#
# Line:
#
# Line:    "msml-dialog-fax-sendrecv": this Control Package supports MSML Dialog
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 3.2.1.  Control Framework Package Names.    "msml-dialog-fax-detect": this Control Package supports MSML Dialog      Fax Detection Package as specified in section 9.11.
#
# Line:
#
# Line:    "msml-audit": this Control Package supports MSML Audit Core Package
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 3.2.1.  Control Framework Package Names.    "msml-dialog-fax-sendrecv": this Control Package supports MSML Dialog      Fax Send/Receive Package as specified in section 9.12.
#
# Line:
#
# Line:    "msml-audit-conf": this Control Package supports MSML Audit
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 3.2.1.  Control Framework Package Names.    "msml-audit": this Control Package supports MSML Audit Core Package      as specified in section 10.1.
#
# Line:
#
# Line:    "msml-audit-conn": this Control Package supports MSML Audit
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 3.2.1.  Control Framework Package Names.    "msml-audit-conf": this Control Package supports MSML Audit      Conference Package as specified in section 10.2.
#
# Line:
#
# Line:    "msml-audit-dialog": this Control Package supports MSML Audit Dialog
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 3.2.1.  Control Framework Package Names.    "msml-audit-conn": this Control Package supports MSML Audit      Connection Package as specified in section 10.3.
#
# Line:
#
# Line:    "msml-audit-stream": this Control Package supports MSML Audit Stream
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 3.2.1.  Control Framework Package Names.    "msml-audit-dialog": this Control Package supports MSML Audit Dialog      Package as specified in section 10.4.
#
# Line:
#
# Line:    An application server using the Control Framework as transport for
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 3.2.1.  Control Framework Package Names.    "msml-audit-stream": this Control Package supports MSML Audit Stream      Package as specified in section 10.5.
#
# Line:
#
# Line: 3.2.2.  Control Framework Messages
# Whitespaces: 0
# Current line has less whitespaces.
# Appending previous chunk: 3.2.1.  Control Framework Package Names.    An application server using the Control Framework as transport for   MSML MUST use one or multiple package names, depending on the service   required from the media server.  The package name(s) are identified   in the "Control-Packages" SIP header that is present in the SIP   INVITE dialog request that creates the control channel, as specified   in [i11].  The "Control-Packages" value MAY be re-negotiated via the   SIP re-INVITE mechanism.
# Updated sections: []
# Updated whitespaces: 0
#
# Line:
#
# Line:    The usage of CONTROL, response, and REPORT messages, as defined in
# Whitespaces: 3
# Current line has more whitespaces.
# Sections: ['3.2.2.  Control Framework Messages']
# Updated whitespaces: 3
#
# Line:
#
# Line:       MSML Core Package "msml"
# Whitespaces: 6
# Current line has more whitespaces.
# Sections: ['3.2.2.  Control Framework Messages', '   The usage of CONTROL, response, and REPORT messages, as defined in   [i11], by each Control Package defined in MSML is different and   described separately in the following sections.']
# Updated whitespaces: 6
#
# Line:
#
# Line:          The application server may send a CONTROL message with a body
# Whitespaces: 9
# Current line has more whitespaces.
# Sections: ['3.2.2.  Control Framework Messages', '   The usage of CONTROL, response, and REPORT messages, as defined in   [i11], by each Control Package defined in MSML is different and   described separately in the following sections.', '      MSML Core Package "msml"']
# Updated whitespaces: 9
#
# Line:
#
# Line:          <msml>: the root element that may contain a list of child
# Whitespaces: 9
# Current line has same number whitespaces.
# Appending previous chunk: 3.2.2.  Control Framework Messages -    The usage of CONTROL, response, and REPORT messages, as defined in   [i11], by each Control Package defined in MSML is different and   described separately in the following sections. -       MSML Core Package "msml".          The application server may send a CONTROL message with a body         of MSML request using the following elements to the MS:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:          <send>: sends an event to the specified recipient within the
# Whitespaces: 9
# Current line has same number whitespaces.
# Appending previous chunk: 3.2.2.  Control Framework Messages -    The usage of CONTROL, response, and REPORT messages, as defined in   [i11], by each Control Package defined in MSML is different and   described separately in the following sections. -       MSML Core Package "msml".          <msml>: the root element that may contain a list of child         elements that request a specific operation.  The child elements         are defined in extended packages (e.g., "msml-conf" and "msml-         dialog").  This element is also the root element that contains         an MSML result and event.
#
# Line:
#
# Line:          The media server replies with a response message containing a
# Whitespaces: 9
# Current line has same number whitespaces.
# Appending previous chunk: 3.2.2.  Control Framework Messages -    The usage of CONTROL, response, and REPORT messages, as defined in   [i11], by each Control Package defined in MSML is different and   described separately in the following sections. -       MSML Core Package "msml".          <send>: sends an event to the specified recipient within the         media server.  Specific event types are defined within the         extended packages.
#
# Line:
#
# Line:          <result>: reports the results of an MSML transaction.
# Whitespaces: 9
# Current line has same number whitespaces.
# Appending previous chunk: 3.2.2.  Control Framework Messages -    The usage of CONTROL, response, and REPORT messages, as defined in   [i11], by each Control Package defined in MSML is different and   described separately in the following sections. -       MSML Core Package "msml".          The media server replies with a response message containing a         MSML result using the following elements:
#
# Line:
#
# Line:          The media server MAY send the MSML event to the application
# Whitespaces: 9
# Current line has same number whitespaces.
# Appending previous chunk: 3.2.2.  Control Framework Messages -    The usage of CONTROL, response, and REPORT messages, as defined in   [i11], by each Control Package defined in MSML is different and   described separately in the following sections. -       MSML Core Package "msml".          <result>: reports the results of an MSML transaction.
#
# Line:
#
# Line:       MSML Conference Core Package "msml-conf"
# Whitespaces: 6
# Current line has less whitespaces.
# Appending previous chunk: 3.2.2.  Control Framework Messages -    The usage of CONTROL, response, and REPORT messages, as defined in   [i11], by each Control Package defined in MSML is different and   described separately in the following sections. -       MSML Core Package "msml".          The media server MAY send the MSML event to the application         server, in a REPORT or CONTROL message, using the element         Framework message to use are defined within the extended
# Updated sections: ['3.2.2.  Control Framework Messages', '   The usage of CONTROL, response, and REPORT messages, as defined in   [i11], by each Control Package defined in MSML is different and   described separately in the following sections.']
# Updated whitespaces: 6
#
# Line:
#
# Line:          This package extends the MSML Core Package to define a
# Whitespaces: 9
# Current line has more whitespaces.
# Sections: ['3.2.2.  Control Framework Messages', '   The usage of CONTROL, response, and REPORT messages, as defined in   [i11], by each Control Package defined in MSML is different and   described separately in the following sections.', '      MSML Conference Core Package "msml-conf"']
# Updated whitespaces: 9
#
# Line:
#
# Line:          The AS can send a CONTROL message with a body of the MSML
# Whitespaces: 9
# Current line has same number whitespaces.
# Appending previous chunk: 3.2.2.  Control Framework Messages -    The usage of CONTROL, response, and REPORT messages, as defined in   [i11], by each Control Package defined in MSML is different and   described separately in the following sections. -       MSML Conference Core Package "msml-conf".          This package extends the MSML Core Package to define a         framework for creation, manipulation, and deletion of a         conference.
#
# Line:
#
# Line:          During the lifetime of a conference, whenever an event occurs,
# Whitespaces: 9
# Current line has same number whitespaces.
# Appending previous chunk: 3.2.2.  Control Framework Messages -    The usage of CONTROL, response, and REPORT messages, as defined in   [i11], by each Control Package defined in MSML is different and   described separately in the following sections. -       MSML Conference Core Package "msml-conf".          The AS can send a CONTROL message with a body of the MSML         request that contains one or multiple conference-related         commands to the MS.  The MS then replies with a response         message with a body of the MSML result to indicate whether or         not the request has been fulfilled.
#
# Line:
#
# Line:          This package does NOT use the REPORT message.
# Whitespaces: 9
# Current line has same number whitespaces.
# Appending previous chunk: 3.2.2.  Control Framework Messages -    The usage of CONTROL, response, and REPORT messages, as defined in   [i11], by each Control Package defined in MSML is different and   described separately in the following sections. -       MSML Conference Core Package "msml-conf".          During the lifetime of a conference, whenever an event occurs,         the media server MAY send CONTROL messages containing MSML         events to notify the application server.  The application         server SHOULD reply with a response message with no MSML body         to acknowledge the event has been received.
#
# Line:
#
# Line:       Dialog Core Package "msml-dialog"
# Whitespaces: 6
# Current line has less whitespaces.
# Appending previous chunk: 3.2.2.  Control Framework Messages -    The usage of CONTROL, response, and REPORT messages, as defined in   [i11], by each Control Package defined in MSML is different and   described separately in the following sections. -       MSML Conference Core Package "msml-conf".          This package does NOT use the REPORT message.
# Updated sections: ['3.2.2.  Control Framework Messages', '   The usage of CONTROL, response, and REPORT messages, as defined in   [i11], by each Control Package defined in MSML is different and   described separately in the following sections.']
# Updated whitespaces: 6
#
# Line:
#
# Line:          This package extends the MSML Core Package to define the
# Whitespaces: 9
# Current line has more whitespaces.
# Sections: ['3.2.2.  Control Framework Messages', '   The usage of CONTROL, response, and REPORT messages, as defined in   [i11], by each Control Package defined in MSML is different and   described separately in the following sections.', '      Dialog Core Package "msml-dialog"']
# Updated whitespaces: 9
#
# Line:
#
# Line:          The application server MAY send CONTROL messages containing a
# Whitespaces: 9
# Current line has same number whitespaces.
# Appending previous chunk: 3.2.2.  Control Framework Messages -    The usage of CONTROL, response, and REPORT messages, as defined in   [i11], by each Control Package defined in MSML is different and   described separately in the following sections. -       Dialog Core Package "msml-dialog".          This package extends the MSML Core Package to define the         structural framework and abstractions for MSML dialogs.
#
# Line:
#
# Line:          <dialogstart>: instantiate an MSML media dialog on a connection
# Whitespaces: 9
# Current line has same number whitespaces.
# Appending previous chunk: 3.2.2.  Control Framework Messages -    The usage of CONTROL, response, and REPORT messages, as defined in   [i11], by each Control Package defined in MSML is different and   described separately in the following sections. -       Dialog Core Package "msml-dialog".          The application server MAY send CONTROL messages containing a         MSML request using the following elements:
#
# Line:
#
# Line:          <dialogend>: terminates an MSML dialog.
# Whitespaces: 9
# Current line has same number whitespaces.
# Appending previous chunk: 3.2.2.  Control Framework Messages -    The usage of CONTROL, response, and REPORT messages, as defined in   [i11], by each Control Package defined in MSML is different and   described separately in the following sections. -       Dialog Core Package "msml-dialog".          <dialogstart>: instantiate an MSML media dialog on a connection         or a conference.
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:          <send>: sends an event and an optional namelist to the dialog,
# Whitespaces: 9
# Current line has same number whitespaces.
# Appending previous chunk: 3.2.2.  Control Framework Messages -    The usage of CONTROL, response, and REPORT messages, as defined in   [i11], by each Control Package defined in MSML is different and   described separately in the following sections. -       Dialog Core Package "msml-dialog".          <dialogend>: terminates an MSML dialog.
#
# Line:
#
# Line:          <exit>: used by the dialog description language to cause the
# Whitespaces: 9
# Current line has same number whitespaces.
# Appending previous chunk: 3.2.2.  Control Framework Messages -    The usage of CONTROL, response, and REPORT messages, as defined in   [i11], by each Control Package defined in MSML is different and   described separately in the following sections. -       Dialog Core Package "msml-dialog".          <send>: sends an event and an optional namelist to the dialog,         dialog group, or dialog primitive.
#
# Line:
#
# Line:          For the <dialogstart> command, the response message MUST
# Whitespaces: 9
# Current line has same number whitespaces.
# Appending previous chunk: 3.2.2.  Control Framework Messages -    The usage of CONTROL, response, and REPORT messages, as defined in   [i11], by each Control Package defined in MSML is different and   described separately in the following sections. -       Dialog Core Package "msml-dialog".          <exit>: used by the dialog description language to cause the         execution of the MSML dialog to terminate.
#
# Line:
#
# Line:          For the <dialogend> and <send> commands, the response message
# Whitespaces: 9
# Current line has same number whitespaces.
# Appending previous chunk: 3.2.2.  Control Framework Messages -    The usage of CONTROL, response, and REPORT messages, as defined in   [i11], by each Control Package defined in MSML is different and   described separately in the following sections. -       Dialog Core Package "msml-dialog".          For the <dialogstart> command, the response message MUST         contain an MSML result that indicates that the dialog has been         started successfully.  The MSML result MAY contain <dialogid>         to return the dialog identifier, if the identifier was assigned         by the media server.  Subsequently, zero or more MSML events         MAY be initiated by the media server in (update) REPORT         messages to report information gathered during the dialog.         Finally, an MSML event "msml.dialog.exit" SHOULD be generated         in a (terminate) REPORT message when the dialog terminates         (e.g., MSML execution of <exit>).
#
# Line:
#
# Line:       Dialog Base Package "msml-dialog-base"
# Whitespaces: 6
# Current line has less whitespaces.
# Appending previous chunk: 3.2.2.  Control Framework Messages -    The usage of CONTROL, response, and REPORT messages, as defined in   [i11], by each Control Package defined in MSML is different and   described separately in the following sections. -       Dialog Core Package "msml-dialog".          For the <dialogend> and <send> commands, the response message         contains the final MSML result that indicates that the request         has either been fulfilled or rejected.
# Updated sections: ['3.2.2.  Control Framework Messages', '   The usage of CONTROL, response, and REPORT messages, as defined in   [i11], by each Control Package defined in MSML is different and   described separately in the following sections.']
# Updated whitespaces: 6
#
# Line:
#
# Line:          This package extends the MSML Dialog Core Package to define a
# Whitespaces: 9
# Current line has more whitespaces.
# Sections: ['3.2.2.  Control Framework Messages', '   The usage of CONTROL, response, and REPORT messages, as defined in   [i11], by each Control Package defined in MSML is different and   described separately in the following sections.', '      Dialog Base Package "msml-dialog-base"']
# Updated whitespaces: 9
#
# Line:
#
# Line:       Dialog Transform Package "msml-dialog-transform"
# Whitespaces: 6
# Current line has less whitespaces.
# Appending previous chunk: 3.2.2.  Control Framework Messages -    The usage of CONTROL, response, and REPORT messages, as defined in   [i11], by each Control Package defined in MSML is different and   described separately in the following sections. -       Dialog Base Package "msml-dialog-base".          This package extends the MSML Dialog Core Package to define a         set of base functionality for MSML dialogs.  The extension         defines individual media primitives, including <play>,         used as child element of <dialogstart>.  This package does not         change the framework message usage as defined by the MSML         Dialog Core Package.
# Updated sections: ['3.2.2.  Control Framework Messages', '   The usage of CONTROL, response, and REPORT messages, as defined in   [i11], by each Control Package defined in MSML is different and   described separately in the following sections.']
# Updated whitespaces: 6
#
# Line:
#
# Line:          This package extends the MSML Dialog Core Package to define a
# ...
# Updated sections: ['3.2.2.  Control Framework Messages', '   The usage of CONTROL, response, and REPORT messages, as defined in   [i11], by each Control Package defined in MSML is different and   described separately in the following sections.', '7.  MSML Core Package', '8.3.  <createconference>', '8.4.  <modifyconference>', '8.5.  <destroyconference>', '8.6.  <audiomix>', '8.7.  <videolayout>', '8.7.3.1.  Voice Activated Switching ("vas")', '8.9.  <modifystream>', '8.11.  <monitor>', '8.12.1.  Audio Stream Properties', '9.6.1.  <dialogstart>', '9.6.2.  <dialogend>', '9.6.5.  <disconnect>', '9.7.2.1.  <dtmfgenexit>', '   Child Elements:', '      <tone1>', '9.7.3.3.  <tonegenexit>', '9.8.  MSML Dialog Group Package', '9.10.  MSML Dialog Speech Package', '9.10.1.5.  <speechexit>', '9.11.1.  <faxdetect>', '9.12.1.5.  <faxnegotiate>', '9.12.1.6.  <faxpagedone>', '9.12.1.7.  <faxobjectdone>', '9.12.1.8.  <faxopcomplete>', '9.12.1.9.  <faxpollstarted>', '10.1.  MSML Audit Core Package', '10.2.1.  State Parameters', '10.2.2.1.  confconfig', '10.2.2.2.  confconfig.audiomix', '10.2.2.3.  confconfig.audiomix.asn', '10.2.2.4.  confconfig.audiomix.n-loudest', '10.2.2.5.  confconfig.videolayout', '10.2.2.6.  confconfig.videolayout.root', '10.2.2.7.  confconfig.videolayout.selector', '10.3.1.  State Parameters', '10.3.2.1.  sipdialog', '11.  Response Codes', '12.2.  Example of a Sidebar Audio Conference', '12.4.  Example of Modifying Video Layout', '13.1.  Announcement', '13.2.  Voice Mail Retrieval', '13.3.  Play and Record', '13.4.  Speech Recognition', '13.5.  Play and Collect', '   The following implements the same functionality, as described above,   using the MSML Dialog Base Package, using the <collect> composite   mechanism for the play and collect operation.', '13.6.  User Controlled Gain', '14.1.  Audit All Conferences', '14.2.  Audit Conference Dialogs', '14.3.  Audit Conference Streams', '14.4.  Audit All Connections', '14.5.  Audit Connection Dialogs', '14.6.  Audit Connection Streams', '16.4.7.  msml-audit-dialog-datatypes.xsd', '16.4.8.  msml-audit-stream-datatypes.xsd']
# Updated whitespaces: 0
#
# Line:
#
# Line:    Adnan Saleem
# Whitespaces: 3
# Current line has more whitespaces.
# Sections: ['3.2.2.  Control Framework Messages', '   The usage of CONTROL, response, and REPORT messages, as defined in   [i11], by each Control Package defined in MSML is different and   described separately in the following sections.', '7.  MSML Core Package', '8.3.  <createconference>', '8.4.  <modifyconference>', '8.5.  <destroyconference>', '8.6.  <audiomix>', '8.7.  <videolayout>', '8.7.3.1.  Voice Activated Switching ("vas")', '8.9.  <modifystream>', '8.11.  <monitor>', '8.12.1.  Audio Stream Properties', '9.6.1.  <dialogstart>', '9.6.2.  <dialogend>', '9.6.5.  <disconnect>', '9.7.2.1.  <dtmfgenexit>', '   Child Elements:', '      <tone1>', '9.7.3.3.  <tonegenexit>', '9.8.  MSML Dialog Group Package', '9.10.  MSML Dialog Speech Package', '9.10.1.5.  <speechexit>', '9.11.1.  <faxdetect>', '9.12.1.5.  <faxnegotiate>', '9.12.1.6.  <faxpagedone>', '9.12.1.7.  <faxobjectdone>', '9.12.1.8.  <faxopcomplete>', '9.12.1.9.  <faxpollstarted>', '10.1.  MSML Audit Core Package', '10.2.1.  State Parameters', '10.2.2.1.  confconfig', '10.2.2.2.  confconfig.audiomix', '10.2.2.3.  confconfig.audiomix.asn', '10.2.2.4.  confconfig.audiomix.n-loudest', '10.2.2.5.  confconfig.videolayout', '10.2.2.6.  confconfig.videolayout.root', '10.2.2.7.  confconfig.videolayout.selector', '10.3.1.  State Parameters', '10.3.2.1.  sipdialog', '11.  Response Codes', '12.2.  Example of a Sidebar Audio Conference', '12.4.  Example of Modifying Video Layout', '13.1.  Announcement', '13.2.  Voice Mail Retrieval', '13.3.  Play and Record', '13.4.  Speech Recognition', '13.5.  Play and Collect', '   The following implements the same functionality, as described above,   using the MSML Dialog Base Package, using the <collect> composite   mechanism for the play and collect operation.', '13.6.  User Controlled Gain', '14.1.  Audit All Conferences', '14.2.  Audit Conference Dialogs', '14.3.  Audit Conference Streams', '14.4.  Audit All Connections', '14.5.  Audit Connection Dialogs', '14.6.  Audit Connection Streams', '16.4.7.  msml-audit-dialog-datatypes.xsd', '16.4.8.  msml-audit-stream-datatypes.xsd', "Authors' Addresses"]
# Updated whitespaces: 3
#
# Line:
#
# Line:    Phone: +1 604 918 6376
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 3.2.2.  Control Framework Messages -    The usage of CONTROL, response, and REPORT messages, as defined in   [i11], by each Control Package defined in MSML is different and   described separately in the following sections. - 7.  MSML Core Package - 8.3.  <createconference> - 8.4.  <modifyconference> - 8.5.  <destroyconference> - 8.6.  <audiomix> - 8.7.  <videolayout> - 8.7.3.1.  Voice Activated Switching ("vas") - 8.9.  <modifystream> - 8.11.  <monitor> - 8.12.1.  Audio Stream Properties - 9.6.1.  <dialogstart> - 9.6.2.  <dialogend> - 9.6.5.  <disconnect> - 9.7.2.1.  <dtmfgenexit> -    Child Elements: -       <tone1> - 9.7.3.3.  <tonegenexit> - 9.8.  MSML Dialog Group Package - 9.10.  MSML Dialog Speech Package - 9.10.1.5.  <speechexit> - 9.11.1.  <faxdetect> - 9.12.1.5.  <faxnegotiate> - 9.12.1.6.  <faxpagedone> - 9.12.1.7.  <faxobjectdone> - 9.12.1.8.  <faxopcomplete> - 9.12.1.9.  <faxpollstarted> - 10.1.  MSML Audit Core Package - 10.2.1.  State Parameters - 10.2.2.1.  confconfig - 10.2.2.2.  confconfig.audiomix - 10.2.2.3.  confconfig.audiomix.asn - 10.2.2.4.  confconfig.audiomix.n-loudest - 10.2.2.5.  confconfig.videolayout - 10.2.2.6.  confconfig.videolayout.root - 10.2.2.7.  confconfig.videolayout.selector - 10.3.1.  State Parameters - 10.3.2.1.  sipdialog - 11.  Response Codes - 12.2.  Example of a Sidebar Audio Conference - 12.4.  Example of Modifying Video Layout - 13.1.  Announcement - 13.2.  Voice Mail Retrieval - 13.3.  Play and Record - 13.4.  Speech Recognition - 13.5.  Play and Collect -    The following implements the same functionality, as described above,   using the MSML Dialog Base Package, using the <collect> composite   mechanism for the play and collect operation. - 13.6.  User Controlled Gain - 14.1.  Audit All Conferences - 14.2.  Audit Conference Dialogs - 14.3.  Audit Conference Streams - 14.4.  Audit All Connections - 14.5.  Audit Connection Dialogs - 14.6.  Audit Connection Streams - 16.4.7.  msml-audit-dialog-datatypes.xsd - 16.4.8.  msml-audit-stream-datatypes.xsd - Authors' Addresses.    Adnan Saleem   RadiSys   4190 Still Creek Drive, Suite 300   Burnaby, BC, V5C 6C6   Canada
#
# Line:
#
# Line:
#
# Line:    Yong Xin
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 3.2.2.  Control Framework Messages -    The usage of CONTROL, response, and REPORT messages, as defined in   [i11], by each Control Package defined in MSML is different and   described separately in the following sections. - 7.  MSML Core Package - 8.3.  <createconference> - 8.4.  <modifyconference> - 8.5.  <destroyconference> - 8.6.  <audiomix> - 8.7.  <videolayout> - 8.7.3.1.  Voice Activated Switching ("vas") - 8.9.  <modifystream> - 8.11.  <monitor> - 8.12.1.  Audio Stream Properties - 9.6.1.  <dialogstart> - 9.6.2.  <dialogend> - 9.6.5.  <disconnect> - 9.7.2.1.  <dtmfgenexit> -    Child Elements: -       <tone1> - 9.7.3.3.  <tonegenexit> - 9.8.  MSML Dialog Group Package - 9.10.  MSML Dialog Speech Package - 9.10.1.5.  <speechexit> - 9.11.1.  <faxdetect> - 9.12.1.5.  <faxnegotiate> - 9.12.1.6.  <faxpagedone> - 9.12.1.7.  <faxobjectdone> - 9.12.1.8.  <faxopcomplete> - 9.12.1.9.  <faxpollstarted> - 10.1.  MSML Audit Core Package - 10.2.1.  State Parameters - 10.2.2.1.  confconfig - 10.2.2.2.  confconfig.audiomix - 10.2.2.3.  confconfig.audiomix.asn - 10.2.2.4.  confconfig.audiomix.n-loudest - 10.2.2.5.  confconfig.videolayout - 10.2.2.6.  confconfig.videolayout.root - 10.2.2.7.  confconfig.videolayout.selector - 10.3.1.  State Parameters - 10.3.2.1.  sipdialog - 11.  Response Codes - 12.2.  Example of a Sidebar Audio Conference - 12.4.  Example of Modifying Video Layout - 13.1.  Announcement - 13.2.  Voice Mail Retrieval - 13.3.  Play and Record - 13.4.  Speech Recognition - 13.5.  Play and Collect -    The following implements the same functionality, as described above,   using the MSML Dialog Base Package, using the <collect> composite   mechanism for the play and collect operation. - 13.6.  User Controlled Gain - 14.1.  Audit All Conferences - 14.2.  Audit Conference Dialogs - 14.3.  Audit Conference Streams - 14.4.  Audit All Connections - 14.5.  Audit Connection Dialogs - 14.6.  Audit Connection Streams - 16.4.7.  msml-audit-dialog-datatypes.xsd - 16.4.8.  msml-audit-stream-datatypes.xsd - Authors' Addresses.    Phone: +1 604 918 6376   EMail : adnan.saleem@radisys.com
#
# Line:
#
# Line:    Phone: +1 604 918 6383
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 3.2.2.  Control Framework Messages -    The usage of CONTROL, response, and REPORT messages, as defined in   [i11], by each Control Package defined in MSML is different and   described separately in the following sections. - 7.  MSML Core Package - 8.3.  <createconference> - 8.4.  <modifyconference> - 8.5.  <destroyconference> - 8.6.  <audiomix> - 8.7.  <videolayout> - 8.7.3.1.  Voice Activated Switching ("vas") - 8.9.  <modifystream> - 8.11.  <monitor> - 8.12.1.  Audio Stream Properties - 9.6.1.  <dialogstart> - 9.6.2.  <dialogend> - 9.6.5.  <disconnect> - 9.7.2.1.  <dtmfgenexit> -    Child Elements: -       <tone1> - 9.7.3.3.  <tonegenexit> - 9.8.  MSML Dialog Group Package - 9.10.  MSML Dialog Speech Package - 9.10.1.5.  <speechexit> - 9.11.1.  <faxdetect> - 9.12.1.5.  <faxnegotiate> - 9.12.1.6.  <faxpagedone> - 9.12.1.7.  <faxobjectdone> - 9.12.1.8.  <faxopcomplete> - 9.12.1.9.  <faxpollstarted> - 10.1.  MSML Audit Core Package - 10.2.1.  State Parameters - 10.2.2.1.  confconfig - 10.2.2.2.  confconfig.audiomix - 10.2.2.3.  confconfig.audiomix.asn - 10.2.2.4.  confconfig.audiomix.n-loudest - 10.2.2.5.  confconfig.videolayout - 10.2.2.6.  confconfig.videolayout.root - 10.2.2.7.  confconfig.videolayout.selector - 10.3.1.  State Parameters - 10.3.2.1.  sipdialog - 11.  Response Codes - 12.2.  Example of a Sidebar Audio Conference - 12.4.  Example of Modifying Video Layout - 13.1.  Announcement - 13.2.  Voice Mail Retrieval - 13.3.  Play and Record - 13.4.  Speech Recognition - 13.5.  Play and Collect -    The following implements the same functionality, as described above,   using the MSML Dialog Base Package, using the <collect> composite   mechanism for the play and collect operation. - 13.6.  User Controlled Gain - 14.1.  Audit All Conferences - 14.2.  Audit Conference Dialogs - 14.3.  Audit Conference Streams - 14.4.  Audit All Connections - 14.5.  Audit Connection Dialogs - 14.6.  Audit Connection Streams - 16.4.7.  msml-audit-dialog-datatypes.xsd - 16.4.8.  msml-audit-stream-datatypes.xsd - Authors' Addresses.    Yong Xin   RadiSys   4190 Still Creek Drive, Suite 300   Burnaby, BC, V5C 6C6   Canada
#
# Line:
#
# Line:
#
# Line:    Garland Sharratt
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 3.2.2.  Control Framework Messages -    The usage of CONTROL, response, and REPORT messages, as defined in   [i11], by each Control Package defined in MSML is different and   described separately in the following sections. - 7.  MSML Core Package - 8.3.  <createconference> - 8.4.  <modifyconference> - 8.5.  <destroyconference> - 8.6.  <audiomix> - 8.7.  <videolayout> - 8.7.3.1.  Voice Activated Switching ("vas") - 8.9.  <modifystream> - 8.11.  <monitor> - 8.12.1.  Audio Stream Properties - 9.6.1.  <dialogstart> - 9.6.2.  <dialogend> - 9.6.5.  <disconnect> - 9.7.2.1.  <dtmfgenexit> -    Child Elements: -       <tone1> - 9.7.3.3.  <tonegenexit> - 9.8.  MSML Dialog Group Package - 9.10.  MSML Dialog Speech Package - 9.10.1.5.  <speechexit> - 9.11.1.  <faxdetect> - 9.12.1.5.  <faxnegotiate> - 9.12.1.6.  <faxpagedone> - 9.12.1.7.  <faxobjectdone> - 9.12.1.8.  <faxopcomplete> - 9.12.1.9.  <faxpollstarted> - 10.1.  MSML Audit Core Package - 10.2.1.  State Parameters - 10.2.2.1.  confconfig - 10.2.2.2.  confconfig.audiomix - 10.2.2.3.  confconfig.audiomix.asn - 10.2.2.4.  confconfig.audiomix.n-loudest - 10.2.2.5.  confconfig.videolayout - 10.2.2.6.  confconfig.videolayout.root - 10.2.2.7.  confconfig.videolayout.selector - 10.3.1.  State Parameters - 10.3.2.1.  sipdialog - 11.  Response Codes - 12.2.  Example of a Sidebar Audio Conference - 12.4.  Example of Modifying Video Layout - 13.1.  Announcement - 13.2.  Voice Mail Retrieval - 13.3.  Play and Record - 13.4.  Speech Recognition - 13.5.  Play and Collect -    The following implements the same functionality, as described above,   using the MSML Dialog Base Package, using the <collect> composite   mechanism for the play and collect operation. - 13.6.  User Controlled Gain - 14.1.  Audit All Conferences - 14.2.  Audit Conference Dialogs - 14.3.  Audit Conference Streams - 14.4.  Audit All Connections - 14.5.  Audit Connection Dialogs - 14.6.  Audit Connection Streams - 16.4.7.  msml-audit-dialog-datatypes.xsd - 16.4.8.  msml-audit-stream-datatypes.xsd - Authors' Addresses.    Phone: +1 604 918 6383   EMail: yong.xin@radiSys.com
#
# Line:
#
# Line:    EMail: garland.sharratt@gmail.com
# Whitespaces: 3
# Current line has same number whitespaces.
# Appending previous chunk: 3.2.2.  Control Framework Messages -    The usage of CONTROL, response, and REPORT messages, as defined in   [i11], by each Control Package defined in MSML is different and   described separately in the following sections. - 7.  MSML Core Package - 8.3.  <createconference> - 8.4.  <modifyconference> - 8.5.  <destroyconference> - 8.6.  <audiomix> - 8.7.  <videolayout> - 8.7.3.1.  Voice Activated Switching ("vas") - 8.9.  <modifystream> - 8.11.  <monitor> - 8.12.1.  Audio Stream Properties - 9.6.1.  <dialogstart> - 9.6.2.  <dialogend> - 9.6.5.  <disconnect> - 9.7.2.1.  <dtmfgenexit> -    Child Elements: -       <tone1> - 9.7.3.3.  <tonegenexit> - 9.8.  MSML Dialog Group Package - 9.10.  MSML Dialog Speech Package - 9.10.1.5.  <speechexit> - 9.11.1.  <faxdetect> - 9.12.1.5.  <faxnegotiate> - 9.12.1.6.  <faxpagedone> - 9.12.1.7.  <faxobjectdone> - 9.12.1.8.  <faxopcomplete> - 9.12.1.9.  <faxpollstarted> - 10.1.  MSML Audit Core Package - 10.2.1.  State Parameters - 10.2.2.1.  confconfig - 10.2.2.2.  confconfig.audiomix - 10.2.2.3.  confconfig.audiomix.asn - 10.2.2.4.  confconfig.audiomix.n-loudest - 10.2.2.5.  confconfig.videolayout - 10.2.2.6.  confconfig.videolayout.root - 10.2.2.7.  confconfig.videolayout.selector - 10.3.1.  State Parameters - 10.3.2.1.  sipdialog - 11.  Response Codes - 12.2.  Example of a Sidebar Audio Conference - 12.4.  Example of Modifying Video Layout - 13.1.  Announcement - 13.2.  Voice Mail Retrieval - 13.3.  Play and Record - 13.4.  Speech Recognition - 13.5.  Play and Collect -    The following implements the same functionality, as described above,   using the MSML Dialog Base Package, using the <collect> composite   mechanism for the play and collect operation. - 13.6.  User Controlled Gain - 14.1.  Audit All Conferences - 14.2.  Audit Conference Dialogs - 14.3.  Audit Conference Streams - 14.4.  Audit All Connections - 14.5.  Audit Connection Dialogs - 14.6.  Audit Connection Streams - 16.4.7.  msml-audit-dialog-datatypes.xsd - 16.4.8.  msml-audit-stream-datatypes.xsd - Authors' Addresses.    Garland Sharratt   Consultant   Vancouver, BC   Canada
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:
#
# Line:

# %%
new_lines
# Out:
# ['. Media Server Markup Language (MSML)',
#  'Abstract. The Media Server Markup Language (MSML) is used to control and invoke many different types of services on IP media servers. The MSML control interface was initially driven by RadiSys with subsequent significant contributions from Intel, Dialogic, and others in the industry. Clients can use it to define how multimedia sessions interact on a media server and to apply services to individuals or groups of users. MSML can be used, for example, to control media server conferencing features such as video layout and audio mixing, create sidebar conferences or personal mixes, and set the properties of media streams. As well, clients can use MSML to define media processing dialogs, which may be used as parts of application interactions with users or conferences. Transformation of media streams to and from users or conferences as well as interactive voice response (IVR) dialogs are examples of such interactions, which are specified using MSML. MSML clients may also invoke dialogs with individual users or with groups of conference participants using VoiceXML.',
#  'Status of This Memo. This document is not an Internet Standards Track specification; it is published for informational purposes.',
#  'Status of This Memo. This is a contribution to the RFC Series, independently of any other RFC stream. The RFC Editor has chosen to publish this document at its discretion and makes no statement about its value for implementation or deployment. Documents approved for publication by the RFC Editor are not a candidate for any level of Internet Standard; see Section 2 of RFC 5741.',
#  'Status of This Memo. Information about the current status of this document, any errata, and how to provide feedback on it may be obtained at http://www.rfc-editor.org/info/rfc5707.',
#  'IESG Note. This RFC is not a candidate for any level of Internet Standard. The IETF disclaims any knowledge of the fitness of this RFC for any purpose and in particular notes that the decision to publish is not based on IETF review for such things as security, congestion control, or inappropriate interaction with deployed protocols. The RFC Editor has chosen to publish this document at its discretion. Readers of this document should exercise caution in evaluating its value for implementation and deployment. See RFC 3932 for more information.',
#  'Copyright Notice. Copyright (c) 2010 IETF Trust and the persons identified as the document authors. All rights reserved.',
#  "Copyright Notice. This document is subject to BCP 78 and the IETF Trust's Legal Provisions Relating to IETF Documents (http://trustee.ietf.org/license-info) in effect on the date of publication of this document. Please review these documents carefully, as they describe your rights and restrictions with respect to this document.",
#  'Introduction. Media servers contain dynamic pools of media resources. Control agents and other users of media servers (called media server clients) can define and create many different services based on how they configure and use those resources. Often, that configuration and the ways in which those resources interact will be changed dynamically over the course of a call, to reflect changes in the way that an application interacts with a user.',
#  'Introduction. For example, a call may undergo an initial IVR dialog before being placed into a conference. Calls may be moved from a main conference to a sidebar conference and then back again. Individual calls may be directly bridged to create small n-way calls or simple sidebars. None of these change the SIP [n1] dialog or RTP [i3] session. Yet these do affect the media flow and processing internal to the media server.',
#  'Introduction. The Media Server Markup Language (MSML) is an XML [n2] language used to control the flow of media streams and services applied to media streams within a media server. It is used to invoke many different types of services on individual sessions, groups of sessions, and conferences. MSML allows the creation of conferences, bridging different sessions together, and bridging sessions into conferences.',
#  'Introduction. MSML may also be used to create user interaction dialogs and allows the application of media transforms to media streams. Media interaction dialogs created using MSML allow construction of IVR dialog sessions to individual users as well as to groups of users participating in a conference. Dialogs may also be specified using other languages, VoiceXML [n5], which support complete single-party application logic to be executed on the media server.',
#  'Introduction. MSML is a transport independent language, such that it does not rely on underlying transport mechanisms and language semantics are independent of transport. However, SIP is a typical and commonly used transport mechanism for MSML, invoked using the SIP URI scheme. This specification defines using MSML dialogs using SIP as the transport mechanism.',
#  'Introduction. A network connection may be established with the media server using SIP. Media received and transmitted on that connection will flow through different media resources on the media server depending on the requested service. Basic Network Media Services with SIP [n7] defines conventions for associating a basic service with a SIP Request-URI. MSML allows services to be dynamically applied and changed by a control agent during the lifetime of the SIP dialog.',
#  'Introduction. MSML has been designed to address the control and manipulation of media processing operations (e.g., announcement, IVR, play and record, automatic speech recognition (ASR), text to speech (TTS), fax, video), as well as control and relationships of media streams (e.g., simple and advanced conferencing). It provides a general- purpose media server control architecture. MSML can additionally be used to invoke other more complex IVR languages such as VoiceXML.',
#  'Introduction. The MSML control interface has been widely deployed in the industry, with numerous client-side and server-side implementations, since 2003. The in-service commercial deployments cover a wide variety of applications including, but not limited to, IP multimedia conferencing, network voice services, IVR, IVVR (interactive voice and video response), and voice/video mail.',
#  'Glossary. Media Server: a general-purpose platform for executing real-time media processing tasks. This is a logical function that maps either to a single physical device or to a portion of a physical device.',
#  'Glossary. Media Server Client: an application that originates MSML requests to a media server and also referred to as a control agent in this specification.',
#  'Glossary. Network Connection: a participant that represents the termination on a media server of one or more RTP [i3] sessions (for example, audio and video) associated with a call. Network connections are established and removed using a session establishment protocol such as SIP. An instance of a network connection is independent of MSML processing instructions applied to it.',
#  'Glossary. Dialog: an automated IVR participant. Examples of dialogs may be announcement players, IVR interfaces, or voice recorders. Dialogs may be defined in MSML or using VoiceXML [n5].',
#  'Glossary. Conference: an intermediary function that provides multimedia mixing and other advanced conferencing services. This specification currently considers conferences with audio and/or video media types, but is extensible to other media types.',
#  'Glossary. Identifier: a name that is used to refer to a specific instance of an object on the media server, such as a conference or a dialog. Identifiers are composed of one or more terms where each term identifies an object class and instance.',
#  'Glossary. Object: the generic term for a media server entity that terminates, originates, or processes media. This specification defines four classes of objects and specifies mechanisms to create them, join them together, and destroy them.',
#  'Glossary. Participant Object: an object in a media server that sources original media in a call and/or receives and terminates media in a call.',
#  'Glossary. Intermediary Object: an object in a media server that acts on media within a call for the benefit of the participants.',
#  'Glossary. Independent Object: an object that can exist on a media server independent of other objects.',
#  'Glossary. Operator: an intermediary transformer that modifies or transforms a media stream. Examples of operators may be audio gain controls, video scaling, or voice masking. MSML defines operators as media transform objects, which transform media using operations such as gain control, when applied to media streams.',
#  'Glossary. Media Stream: a single media flow between two objects. A media stream has a media type and may be unidirectional or bidirectional.',
#  'MSML SIP Usage. SIP is used to create and modify media sessions with a media server according to the procedures defined in RFC 3261 [n1]. Often, SIP third party call control [i4] will be used to create sessions to a media server on behalf of end users. MSML is used to define and change the service that a user connected to a media server will receive. MSML clients are application servers, soft-switches, or other forms of control agents, and SHOULD have an authorized security relationship with the media server. MSML itself does not define authorization mechanisms.',
#  'MSML SIP Usage. MSML transactions are originated based upon events that occur in the application domain. These events may be independent from any media or user interaction. For example, an application may wish to play an announcement to a conference warning that its scheduled completion time is approaching. Applications themselves are structured in many different ways. Their structure and requirements contribute to their selection of protocols and languages. To accommodate differing application needs, MSML has been designed to be neutral to other languages and independent of the transport used to carry it.',
#  'MSML SIP Usage. MSML is purposely designed to be transport independent. In this release of the specification, SIP INFO [i5] and SIP Control Framework [i11] have been chosen for transport mechanisms for MSML, as described in the following sections.',
#  'SIP INFO. SIP INVITE and INFO [i5] requests and responses MAY be used to carry MSML. INFO requests allow asynchronous mid-call messages within SIP with few additional semantics. In addition, there are existing widely deployed implementations of that method, it aids in initial developments that are closely coupled with SIP session establishment, and it allows MSML to be directly associated with user dialogs when third party call control is used.',
#  'SIP INFO. Although INFO is sometimes considered not to be a suitable general- purpose transport mechanism for messages within SIP, there have been proposals to make it more acceptable. MSML may evolve to include other SIP usage and/or to work with other protocols or as a stand- alone protocol established through SIP, in future releases of this document.',
#  'SIP INFO. MSML supports several models for client interaction. When clients use 3PCC to establish media sessions on behalf of end users, clients will have a SIP dialog for each media session. MSML MAY be sent on these dialogs. However the targets of MSML actions are not inferred from the session associated with the SIP dialog. The targets of MSML actions are always explicitly specified using identifiers as previously defined.',
#  'SIP INFO. An application, after interacting with a user, may want to affect multiple objects within a media server. For example, tones or messages are often played to a conference when connections are added or removed. A separate message may also be played to a participant as they are joined, or to moderators. Explicit identifiers, that is, not inferred from a transport mechanism, allow these multiple actions to be easily grouped into a single transaction sent on any SIP dialog.',
#  'SIP INFO. MSML also supports a model of dedicated control associations. This supports decoupled application architectures where a client can control media server services without also establishing all of the media sessions itself. Control associations are created using SIP, but they do not have any associated media session. Although initially INFO messages will be sent on this SIP dialog, just as with dialogs associated with media sessions, it is possible that in the future, the SIP dialog will be used to establish a separate control session (defined in SDP [n9]) that does not use SIP as the transport for MSML messages.',
#  'SIP INFO. A media server using MSML also sends asynchronous events to a client using MSML scripts in SIP INFO. Events are sent based on previous MSML requests and are sent within the SIP dialog on which the MSML request that caused the event to be generated was received. If this dialog no longer exists when the event is generated, the event is discarded.',
#  'SIP INFO. Events may be generated during the execution of a dialog created by a user input. VoiceXML dialogs, on the other hand, generally interact with other servers outside of MSML using HTTP.',
#  'SIP INFO. An event is also generated when the execution of a dialog terminates, because of either completion or failure. The exact information returned is dependent on the dialog language, the capabilities of the dialog execution environment, and what was requested by the dialog. Both MSML and VoiceXML [n5] allow information to be returned when they exit. These events may be sent in a SIP INFO or a SIP BYE. SIP BYE is used when the dialog itself specifies that the connection should be disconnected, for example, through the use of the',
#  'SIP INFO. Conferences may also generate events based upon their configuration. An example of this is the notification of the set of active speakers.',
#  'SIP Control Framework. The SIP Control Framework [i11] MAY be used as a transport mechanism for MSML.',
#  'SIP Control Framework. The Control Framework provides a generic approach for establishment and reporting capabilities of remotely initiated commands. The framework utilizes many functions provided by the Session Initiation Protocol (SIP) [n1] for the rendezvous and establishment of a reliable channel for control interactions. Compared to SIP INFO, the',
#  'SIP Control Framework. SIP Control Framework is a more general-purpose transport mechanism and one that is not constrained by limitations of the SIP INFO mechanism.',
#  'SIP Control Framework. The Control Framework also introduces the concept of a Control Package, which is an explicit usage of the Control Framework for a particular interaction set. This specification has already specified a list of packages for MSML to control the media server in many aspects, including basic dialog, advanced conferencing, advanced dialog, and audit service. Each of these packages has a unique Control Package name assigned in order for MSML to be used with the Control Framework.',
#  'SIP Control Framework. This section fulfills the mandatory requirement for information that MUST be specified during the definition of a Control Framework Package, as detailed in SIP Control Framework [i11].',
#  'Control Framework Package Names. The Control Framework [i11] requires a Control Package definition to specify and register a unique name.',
#  'Control Framework Package Names. MSML specification defines Control Package names using a hierarchical scheme to indicate the inherited relationship across packages. For example, package "msml-x" is derived from package "msml", and package "msml-x-y" is derived from package "msml-x".',
#  'Control Framework Package Names. The following is a list of Control Package names reserved by the MSML specification.',
#  'Control Framework Package Names. "msml": this Control Package supports MSML Core Package as specified in section 7.',
#  'Control Framework Package Names. "msml-conf": this Control Package supports MSML Conference Core Package as specified in section 8.',
#  'Control Framework Package Names. "msml-dialog": this Control Package supports MSML Dialog Core Package as specified in section 9.6.',
#  'Control Framework Package Names. "msml-dialog-base": this Control Package supports MSML Dialog Base Package as specified in section 9.7.',
#  'Control Framework Package Names. "msml-dialog-group": this Control Package supports MSML Dialog Group Package as specified in section 9.8.',
#  'Control Framework Package Names. "msml-dialog-transform": this Control Package supports MSML Dialog Transform Package as specified in section 9.9.',
#  'Control Framework Package Names. "msml-dialog-speech": this Control Package supports MSML Dialog Speech Package as specified in section 9.10.',
#  'Control Framework Package Names. "msml-dialog-fax-detect": this Control Package supports MSML Dialog Fax Detection Package as specified in section 9.11.',
#  'Control Framework Package Names. "msml-dialog-fax-sendrecv": this Control Package supports MSML Dialog Fax Send/Receive Package as specified in section 9.12.',
#  'Control Framework Package Names. "msml-audit": this Control Package supports MSML Audit Core Package as specified in section 10.1.',
#  'Control Framework Package Names. "msml-audit-conf": this Control Package supports MSML Audit Conference Package as specified in section 10.2.',
#  'Control Framework Package Names. "msml-audit-conn": this Control Package supports MSML Audit Connection Package as specified in section 10.3.',
#  'Control Framework Package Names. "msml-audit-dialog": this Control Package supports MSML Audit Dialog Package as specified in section 10.4.',
#  'Control Framework Package Names. "msml-audit-stream": this Control Package supports MSML Audit Stream Package as specified in section 10.5.',
#  'Control Framework Package Names. An application server using the Control Framework as transport for MSML MUST use one or multiple package names, depending on the service required from the media server. The package name(s) are identified in the "Control-Packages" SIP header that is present in the SIP INVITE dialog request that creates the control channel, as specified in [i11]. The "Control-Packages" value MAY be re-negotiated via the SIP re-INVITE mechanism.',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - MSML Core Package "msml". The application server may send a CONTROL message with a body of MSML request using the following elements to the MS:',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - MSML Core Package "msml". <msml>: the root element that may contain a list of child elements that request a specific operation. The child elements are defined in extended packages (e.g., "msml-conf" and "msml- dialog"). This element is also the root element that contains an MSML result and event.',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - MSML Core Package "msml". <send>: sends an event to the specified recipient within the media server. Specific event types are defined within the extended packages.',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - MSML Core Package "msml". The media server replies with a response message containing a MSML result using the following elements:',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - MSML Core Package "msml". <result>: reports the results of an MSML transaction.',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - MSML Core Package "msml". The media server MAY send the MSML event to the application server, in a REPORT or CONTROL message, using the element Framework message to use are defined within the extended',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - MSML Conference Core Package "msml-conf". This package extends the MSML Core Package to define a framework for creation, manipulation, and deletion of a conference.',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - MSML Conference Core Package "msml-conf". The AS can send a CONTROL message with a body of the MSML request that contains one or multiple conference-related commands to the MS. The MS then replies with a response message with a body of the MSML result to indicate whether or not the request has been fulfilled.',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - MSML Conference Core Package "msml-conf". During the lifetime of a conference, whenever an event occurs, the media server MAY send CONTROL messages containing MSML events to notify the application server. The application server SHOULD reply with a response message with no MSML body to acknowledge the event has been received.',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - MSML Conference Core Package "msml-conf". This package does NOT use the REPORT message.',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - Dialog Core Package "msml-dialog". This package extends the MSML Core Package to define the structural framework and abstractions for MSML dialogs.',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - Dialog Core Package "msml-dialog". The application server MAY send CONTROL messages containing a MSML request using the following elements:',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - Dialog Core Package "msml-dialog". <dialogstart>: instantiate an MSML media dialog on a connection or a conference.',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - Dialog Core Package "msml-dialog". <dialogend>: terminates an MSML dialog.',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - Dialog Core Package "msml-dialog". <send>: sends an event and an optional namelist to the dialog, dialog group, or dialog primitive.',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - Dialog Core Package "msml-dialog". <exit>: used by the dialog description language to cause the execution of the MSML dialog to terminate.',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - Dialog Core Package "msml-dialog". For the <dialogstart> command, the response message MUST contain an MSML result that indicates that the dialog has been started successfully. The MSML result MAY contain <dialogid> to return the dialog identifier, if the identifier was assigned by the media server. Subsequently, zero or more MSML events MAY be initiated by the media server in (update) REPORT messages to report information gathered during the dialog. Finally, an MSML event "msml.dialog.exit" SHOULD be generated in a (terminate) REPORT message when the dialog terminates (e.g., MSML execution of <exit>).',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - Dialog Core Package "msml-dialog". For the <dialogend> and <send> commands, the response message contains the final MSML result that indicates that the request has either been fulfilled or rejected.',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - Dialog Base Package "msml-dialog-base". This package extends the MSML Dialog Core Package to define a set of base functionality for MSML dialogs. The extension defines individual media primitives, including <play>, used as child element of <dialogstart>. This package does not change the framework message usage as defined by the MSML Dialog Core Package.',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - Dialog Transform Package "msml-dialog-transform". This package extends the MSML Dialog Core Package to define a set of transform primitives that works as filter on half-duplex media streams. The extension defines transform primitives, that MAY be used as child elements of <dialogstart>. This package does not change the framework message usage as defined by the MSML Dialog Core Package.',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - Dialog Group Package "msml-dialog-group". This package extends the MSML Dialog Core, Base, and Transform Packages to define a single control flow construct that specifies concurrent execution of multiple media primitives. The extension defines the <group> element that MAY be used as a child element of <dialogstart> to enclose multiple media',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - Dialog Group Package "msml-dialog-group". primitives, such that they can be executed concurrently. This package does not change the framework message usage as defined by the MSML Dialog Core Package.',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - Dialog Speech Package "msml-dialog-speech". This package extends the MSML Dialog Core and MSML Base Package to define functionality that MAY be used for automatic speech recognition and text to speech. The extension extends the',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - Dialog Speech Package "msml-dialog-speech". For <dialogstart>, it defines a new child element <speech> to activate grammars or user input rules associated with speech recognition. For <play>, it defines a new child element <tts> to initiate the text-to-speech service.',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - Dialog Speech Package "msml-dialog-speech". This package does not change the framework message usage as defined by the MSML Dialog Core Package.',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - Dialog Fax Detection Package "msml-dialog-fax-detect". This package extends the MSML Dialog Core Package to define primitives provide fax detection service. The extension defines a primitive <faxdetect> to be used as a child element of <dialogstart>. This package does not change the framework message usage as defined by the MSML Dialog Core Package.',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - Dialog Fax Send/Receive Package "msml-dialog-fax-sendrecv". This package extends the MSML Dialog Core Package to define primitives that allow a media server to provide fax send or receive service. The extension defines new primitives <dialogstart>. This package does not change the framework message usage as defined by the MSML Dialog Core Package.',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - Dialog Audit Core Package "msml-audit". This package extends the MSML Core Package to define a framework for auditing media resource(s) allocated on the media',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - Dialog Audit Core Package "msml-audit". This package follows a simple request/response transaction, allowing the application server to send CONTROL messages containing MSML <audit> requests. The media server MUST reply with a response message containing the result. The result is contained within the <auditresult> element, returning the queried state information.',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - Dialog Audit Core Package "msml-audit". This package does NOT use the REPORT message.',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - Dialog Audit Conference Package "msml-audit-conf". This package extends the MSML Audit Core Package to define conference specific states that MAY be queried via the <audit> command and the corresponding response MUST be returned by the framework message usage as defined by the MSML Audit Core',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - Dialog Audit Connection Package "msml-audit-conn". This package extends the MSML Audit Core Package to define connection specific states that MAY be queried via the <audit> command and the corresponding response MUST be returned by the framework message usage as defined by the MSML Audit Core',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - Dialog Audit Dialog Package "msml-audit-dialog". This package extends the MSML Audit Core Package to define dialog specific states that MAY be queried via the <audit> command and the corresponding response MUST be returned by the framework message usage as defined by the MSML Audit Core',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - Dialog Audit Stream Package "msml-audit-stream". This package extends the MSML Audit Core Package to define stream specific states that MAY be queried via the <audit> command and the corresponding response MUST returned by the framework message usage as defined by the MSML Audit Core',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - 3.2.3. Common XML Support. The XML schema described in [i11] MUST be supported by all Control Packages defined by MSML. However, the "connection-id" value MUST be constructed as defined by MSML (i.e., the identifier MUST contain a local dialog tag only, while the SIP Control Framework [i11] requires that the "connection-id" contain both local and remote dialog tags).',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - 3.2.4. Control Message Body. A valid CONTROL body message MUST conform to the MSML schema, as included in this specification, for the MSML package(s) used.',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - 3.2.5. REPORT Message Body. A valid REPORT body message MUST conform to the MSML schema, as included in this specification, for the MSML package(s) used.',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections.. 4. Language Structure',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - 4.1. Package Scheme. The primary mechanism for extending MSML is the "package". A package is an integrated set of one or more XML schemas that define additional features and functions via new or extended use of elements and attributes. Each package, except for those defined in the current document, is defined in a separate standards document, e.g., an Internet Draft or an RFC. All packages that extend the base MSML functionality MUST include references to the MSML base set of schemas provided in the Internet Drafts. A schema in a package MUST only extend MSML; that is, it must not alter the existing specification.',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - 4.1. Package Scheme. A particular MSML script will include references to all the schemas defining the packages whose elements and attributes it makes use of. A particular script MUST reference MSML base and optionally extension package(s). See the IANA Considerations section.',
#  "Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - 4.1. Package Scheme. Each package MUST define its own namespace so that elements or attributes with the same name in different packages do not conflict. A script using a particular element or attribute MUST prefix the namespace name on that element or attribute's name if it is defined in a package (as opposed to being defined in the base).",
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - 4.1. Package Scheme. MSML consists of a core package that provides structure without support for any specific feature set. Additional packages, relying on the core package, provide functional features. Any combination of additional packages may be used along with the core package. The following describes the set of MSML packages defined in this document.',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - 4.1. Package Scheme. |Dialog| |Dialog | |Dialog| |Dialog| |Dialog| |Dialog | |',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - 4.1. Package Scheme - o MSML Core Package (Mandatory). Describes the minimum base framework that MUST be implemented to support additional core packages.',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - 4.1. Package Scheme - o MSML Conference Core Package (Conditionally Mandatory, for Conferencing). Describes the audio and multimedia basic and advanced conferencing package that MAY be implemented.',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - 4.1. Package Scheme - o MSML Dialog Core Package (Conditionally Mandatory, for Dialogs). Describes the dialog core package that MUST be implemented for any dialog services. However, systems supporting conferencing only, MAY omit support for MSML dialogs. The MSML Dialog Core Package specifies the framework within which additional dialog packages are supported. The MSML Dialog Base Package MUST be supported, while all other dialog packages MAY be supported.',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - 4.1. Package Scheme - o MSML Dialog Core Package (Conditionally Mandatory, for Dialogs). o MSML Dialog Base Package (Conditionally Mandatory, for Dialogs)',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - 4.1. Package Scheme - o MSML Dialog Core Package (Conditionally Mandatory, for Dialogs). o MSML Dialog Group Package (Optional)',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - 4.1. Package Scheme - o MSML Dialog Core Package (Conditionally Mandatory, for Dialogs). o MSML Dialog Transform Package (Optional)',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - 4.1. Package Scheme - o MSML Dialog Core Package (Conditionally Mandatory, for Dialogs). o MSML Dialog Fax Detection Package (Optional)',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - 4.1. Package Scheme - o MSML Dialog Core Package (Conditionally Mandatory, for Dialogs). o MSML Dialog Fax Send/Receive Package (Optional)',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - 4.1. Package Scheme - o MSML Dialog Core Package (Conditionally Mandatory, for Dialogs). o MSML Dialog Speech Package (Optional)',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - 4.1. Package Scheme - o MSML Audit Core Package (Conditionally Mandatory, for Auditing). Describes the audit core package that MUST be implemented to support auditing services. The MSML audit core package specifies the framework within which additional audit packages are supported.',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - 4.1. Package Scheme - o MSML Audit Core Package (Conditionally Mandatory, for Auditing). o MSML Audit Conference Package (Conditionally Mandatory, for Auditing Conference, Conference Dialog, and Conference Stream)',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - 4.1. Package Scheme - o MSML Audit Core Package (Conditionally Mandatory, for Auditing). o MSML Audit Connection Package (Conditionally Mandatory, for Auditing Connection, Connection Dialog, and Connection Stream)',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - 4.1. Package Scheme - o MSML Audit Core Package (Conditionally Mandatory, for Auditing). o MSML Audit Dialog Package (Conditionally Mandatory, for Auditing Dialog, and MUST be used with either MSML Audit Conference Package or MSML Audit Connection Package)',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - 4.1. Package Scheme - o MSML Audit Core Package (Conditionally Mandatory, for Auditing). o MSML Audit Stream Package (Conditionally Mandatory, for Auditing Stream, and MUST be used with either MSML Audit Conference Package or MSML Audit Connection Package)',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - 4.1. Package Scheme. The formal process for defining extensions to MSML dialogs is to define a new package. The new package MUST provide a text description of what extensions are included and how they work. It MUST also define an XML schema file (if applicable) that defines the new package (which may be through extension, restriction of an existing package, or a specific profile of an existing package). Dependencies upon other packages MUST be stated. For example, a package that extends or restricts has a dependency on the original package specification. Finally, the new package MUST be assigned a unique name and version.',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - 4.1. Package Scheme - The types of things that can be defined in new packages are:. o new primitives',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - 4.1. Package Scheme - The types of things that can be defined in new packages are:. o extensions to existing primitives (events, shadow variables, attributes, content)',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - 4.1. Package Scheme - The types of things that can be defined in new packages are:. o new recognition grammars for existing primitives',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - 4.1. Package Scheme - The types of things that can be defined in new packages are:. o new markup languages for speech generation',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - 4.1. Package Scheme - The types of things that can be defined in new packages are:. o languages for specifying a topology schema',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - 4.1. Package Scheme - The types of things that can be defined in new packages are:. o new predefined topology schemas',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - 4.1. Package Scheme - The types of things that can be defined in new packages are:. o new variables / segment types (sets & languages)',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - 4.1. Package Scheme - The types of things that can be defined in new packages are:. o new control flow elements',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - 4.1. Package Scheme. MSML packages are assembled together to form a specific MSML profile that is shared between different implementations. The base MSML dialog profiles that are defined in this document consist of the MSML Core Package, MSML Dialog Core Package, MSML Dialog Base Package, MSML Dialog Group Package, MSML Transform Package, MSML Fax Packages, and the MSML Speech Package.',
# ...
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - 7. MSML Core Package - 8.3. <createconference> - 8.4. <modifyconference> - 8.5. <destroyconference> - 8.6. <audiomix> - 8.7. <videolayout> - 8.7.3.1. Voice Activated Switching ("vas") - 8.9. <modifystream> - 8.11. <monitor> - 8.12.1. Audio Stream Properties - 9.6.1. <dialogstart> - 9.6.2. <dialogend> - 9.6.5. <disconnect> - 9.7.2.1. <dtmfgenexit> - Child Elements: - <tone1> - 9.7.3.3. <tonegenexit> - 9.8. MSML Dialog Group Package - 9.10. MSML Dialog Speech Package - 9.10.1.5. <speechexit> - 9.11.1. <faxdetect> - 9.12.1.5. <faxnegotiate> - 9.12.1.6. <faxpagedone> - 9.12.1.7. <faxobjectdone> - 9.12.1.8. <faxopcomplete> - 9.12.1.9. <faxpollstarted> - 10.1. MSML Audit Core Package - 10.2.1. State Parameters - 10.2.2.1. confconfig - 10.2.2.2. confconfig.audiomix - 10.2.2.3. confconfig.audiomix.asn - 10.2.2.4. confconfig.audiomix.n-loudest - 10.2.2.5. confconfig.videolayout - 10.2.2.6. confconfig.videolayout.root - 10.2.2.7. confconfig.videolayout.selector - 10.3.1. State Parameters - 10.3.2.1. sipdialog - 11. Response Codes - 12.2. Example of a Sidebar Audio Conference - 12.4. Example of Modifying Video Layout - 13.1. Announcement - 13.2. Voice Mail Retrieval - 13.3. Play and Record - 13.4. Speech Recognition - 13.5. Play and Collect - The following implements the same functionality, as described above, using the MSML Dialog Base Package, using the <collect> composite mechanism for the play and collect operation. - 13.6. User Controlled Gain - 14.1. Audit All Conferences - 14.2. Audit Conference Dialogs - 14.3. Audit Conference Streams - 14.4. Audit All Connections - 14.5. Audit Connection Dialogs - 14.6. Audit Connection Streams - 14.7. Audit Connection with Selective States - This example describes an audit of a specific connection, querying associated SIP dialog ID and SDP info. - 16. XML Schema - <xs:schema xmlns:xs="http://www.w3.org/2001/XMLSchema" elementFormDefault="qualified" attributeFormDefault="unqualified"> <xs:include schemaLocation="msml-core-datatypes.xsd"/> <xs:include schemaLocation="msml-conf-core-datatypes.xsd"/> <xs:include schemaLocation="msml-dialog-core-datatypes.xsd"/> <xs:include schemaLocation="msml-dialog-base-datatypes.xsd"/> <xs:include schemaLocation="msml-dialog-transform-datatypes.xsd"/> <xs:include schemaLocation="msml-dialog-group-datatypes.xsd"/> <xs:include schemaLocation="msml-dialog-speech-datatypes.xsd"/> <xs:include schemaLocation="msml-dialog-fax-detect-datatypes.xsd"/> <xs:include schemaLocation="msml-dialog-fax-sendrecv- <xs:include schemaLocation="msml-audit-core-datatypes.xsd"/> - 16.1.1. msml-core.xsd - 16.1.2. msml-core-datatypes.xsd - <xs:schema xmlns:xs="http://www.w3.org/2001/XMLSchema" elementFormDefault="qualified" attributeFormDefault="unqualified"> <xs:include schemaLocation="msml-core-datatypes.xsd"/> <xs:group name="momlRequest"> <xs:choice> <xs:group ref="executeType"/>. 16.3.4. msml-dialog-base-datatypes.xsd',
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - 7. MSML Core Package - 8.3. <createconference> - 8.4. <modifyconference> - 8.5. <destroyconference> - 8.6. <audiomix> - 8.7. <videolayout> - 8.7.3.1. Voice Activated Switching ("vas") - 8.9. <modifystream> - 8.11. <monitor> - 8.12.1. Audio Stream Properties - 9.6.1. <dialogstart> - 9.6.2. <dialogend> - 9.6.5. <disconnect> - 9.7.2.1. <dtmfgenexit> - Child Elements: - <tone1> - 9.7.3.3. <tonegenexit> - 9.8. MSML Dialog Group Package - 9.10. MSML Dialog Speech Package - 9.10.1.5. <speechexit> - 9.11.1. <faxdetect> - 9.12.1.5. <faxnegotiate> - 9.12.1.6. <faxpagedone> - 9.12.1.7. <faxobjectdone> - 9.12.1.8. <faxopcomplete> - 9.12.1.9. <faxpollstarted> - 10.1. MSML Audit Core Package - 10.2.1. State Parameters - 10.2.2.1. confconfig - 10.2.2.2. confconfig.audiomix - 10.2.2.3. confconfig.audiomix.asn - 10.2.2.4. confconfig.audiomix.n-loudest - 10.2.2.5. confconfig.videolayout - 10.2.2.6. confconfig.videolayout.root - 10.2.2.7. confconfig.videolayout.selector - 10.3.1. State Parameters - 10.3.2.1. sipdialog - 11. Response Codes - 12.2. Example of a Sidebar Audio Conference - 12.4. Example of Modifying Video Layout - 13.1. Announcement - 13.2. Voice Mail Retrieval - 13.3. Play and Record - 13.4. Speech Recognition - 13.5. Play and Collect - The following implements the same functionality, as described above, using the MSML Dialog Base Package, using the <collect> composite mechanism for the play and collect operation. - 13.6. User Controlled Gain - 14.1. Audit All Conferences - 14.2. Audit Conference Dialogs - 14.3. Audit Conference Streams - 14.4. Audit All Connections - 14.5. Audit Connection Dialogs - 14.6. Audit Connection Streams - 14.7. Audit Connection with Selective States - This example describes an audit of a specific connection, querying associated SIP dialog ID and SDP info. - 16. XML Schema - <xs:schema xmlns:xs="http://www.w3.org/2001/XMLSchema" elementFormDefault="qualified" attributeFormDefault="unqualified"> <xs:include schemaLocation="msml-core-datatypes.xsd"/> <xs:include schemaLocation="msml-conf-core-datatypes.xsd"/> <xs:include schemaLocation="msml-dialog-core-datatypes.xsd"/> <xs:include schemaLocation="msml-dialog-base-datatypes.xsd"/> <xs:include schemaLocation="msml-dialog-transform-datatypes.xsd"/> <xs:include schemaLocation="msml-dialog-group-datatypes.xsd"/> <xs:include schemaLocation="msml-dialog-speech-datatypes.xsd"/> <xs:include schemaLocation="msml-dialog-fax-detect-datatypes.xsd"/> <xs:include schemaLocation="msml-dialog-fax-sendrecv- <xs:include schemaLocation="msml-audit-core-datatypes.xsd"/> - 16.1.1. msml-core.xsd - 16.1.2. msml-core-datatypes.xsd - <xs:schema xmlns:xs="http://www.w3.org/2001/XMLSchema" elementFormDefault="qualified" attributeFormDefault="unqualified"> <xs:include schemaLocation="msml-core-datatypes.xsd"/> <xs:group name="momlRequest"> <xs:choice> <xs:group ref="executeType"/> - <xs:schema xmlns:xs="http://www.w3.org/2001/XMLSchema" elementFormDefault="unqualified" attributeFormDefault="unqualified"> <xs:include schemaLocation="msml-dialog-core-datatypes.xsd"/> <xs:import namespace="http://www.w3.org/XML/1998/namespace" schemaLocation="http://www.w3.org/2001/xml.xsd"/> <xs:element name="play" substitutionGroup="primitive"> <xs:complexType> <xs:complexContent> <xs:extension base="primitiveType"> <xs:sequence> <xs:choice maxOccurs="unbounded"> <xs:element name="audio" minOccurs="0" maxOccurs="unbounded"> <xs:complexType> <xs:attribute name="uri" type="xs:anyURI" use="required"/> <xs:attribute name="iterate" type="iterate.datatype" <xs:attribute name="format" type="xs:string" use="optional"/> - <xs:attribute name="audiosamplerate" type="xs:positiveInteger" <xs:attribute name="audiosamplesize" type="xs:positiveInteger" <xs:attribute ref="xml:lang"/> </xs:complexType> <xs:eleme ...
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - 7. MSML Core Package - 8.3. <createconference> - 8.4. <modifyconference> - 8.5. <destroyconference> - 8.6. <audiomix> - 8.7. <videolayout> - 8.7.3.1. Voice Activated Switching ("vas") - 8.9. <modifystream> - 8.11. <monitor> - 8.12.1. Audio Stream Properties - 9.6.1. <dialogstart> - 9.6.2. <dialogend> - 9.6.5. <disconnect> - 9.7.2.1. <dtmfgenexit> - Child Elements: - <tone1> - 9.7.3.3. <tonegenexit> - 9.8. MSML Dialog Group Package - 9.10. MSML Dialog Speech Package - 9.10.1.5. <speechexit> - 9.11.1. <faxdetect> - 9.12.1.5. <faxnegotiate> - 9.12.1.6. <faxpagedone> - 9.12.1.7. <faxobjectdone> - 9.12.1.8. <faxopcomplete> - 9.12.1.9. <faxpollstarted> - 10.1. MSML Audit Core Package - 10.2.1. State Parameters - 10.2.2.1. confconfig - 10.2.2.2. confconfig.audiomix - 10.2.2.3. confconfig.audiomix.asn - 10.2.2.4. confconfig.audiomix.n-loudest - 10.2.2.5. confconfig.videolayout - 10.2.2.6. confconfig.videolayout.root - 10.2.2.7. confconfig.videolayout.selector - 10.3.1. State Parameters - 10.3.2.1. sipdialog - 11. Response Codes - 12.2. Example of a Sidebar Audio Conference - 12.4. Example of Modifying Video Layout - 13.1. Announcement - 13.2. Voice Mail Retrieval - 13.3. Play and Record - 13.4. Speech Recognition - 13.5. Play and Collect - The following implements the same functionality, as described above, using the MSML Dialog Base Package, using the <collect> composite mechanism for the play and collect operation. - 13.6. User Controlled Gain - 14.1. Audit All Conferences - 14.2. Audit Conference Dialogs - 14.3. Audit Conference Streams - 14.4. Audit All Connections - 14.5. Audit Connection Dialogs - 14.6. Audit Connection Streams - 14.7. Audit Connection with Selective States - This example describes an audit of a specific connection, querying associated SIP dialog ID and SDP info. - 16. XML Schema - <xs:schema xmlns:xs="http://www.w3.org/2001/XMLSchema" elementFormDefault="qualified" attributeFormDefault="unqualified"> <xs:include schemaLocation="msml-core-datatypes.xsd"/> <xs:include schemaLocation="msml-conf-core-datatypes.xsd"/> <xs:include schemaLocation="msml-dialog-core-datatypes.xsd"/> <xs:include schemaLocation="msml-dialog-base-datatypes.xsd"/> <xs:include schemaLocation="msml-dialog-transform-datatypes.xsd"/> <xs:include schemaLocation="msml-dialog-group-datatypes.xsd"/> <xs:include schemaLocation="msml-dialog-speech-datatypes.xsd"/> <xs:include schemaLocation="msml-dialog-fax-detect-datatypes.xsd"/> <xs:include schemaLocation="msml-dialog-fax-sendrecv- <xs:include schemaLocation="msml-audit-core-datatypes.xsd"/> - 16.1.1. msml-core.xsd - 16.1.2. msml-core-datatypes.xsd - <xs:schema xmlns:xs="http://www.w3.org/2001/XMLSchema" elementFormDefault="qualified" attributeFormDefault="unqualified"> <xs:include schemaLocation="msml-core-datatypes.xsd"/> <xs:group name="momlRequest"> <xs:choice> <xs:group ref="executeType"/> - <xs:schema xmlns:xs="http://www.w3.org/2001/XMLSchema" elementFormDefault="unqualified" attributeFormDefault="unqualified"> <xs:include schemaLocation="msml-dialog-core-datatypes.xsd"/> <xs:import namespace="http://www.w3.org/XML/1998/namespace" schemaLocation="http://www.w3.org/2001/xml.xsd"/> <xs:element name="play" substitutionGroup="primitive"> <xs:complexType> <xs:complexContent> <xs:extension base="primitiveType"> <xs:sequence> <xs:choice maxOccurs="unbounded"> <xs:element name="audio" minOccurs="0" maxOccurs="unbounded"> <xs:complexType> <xs:attribute name="uri" type="xs:anyURI" use="required"/> <xs:attribute name="iterate" type="iterate.datatype" <xs:attribute name="format" type="xs:string" use="optional"/>. <xs:enumeration value="generate"/> <xs:enumeration value="suspend"/> </xs:restriction> </xs:simpleType> </xs:attribute> <xs:attribute name="maxtime" type="posDuration.datatype" <xs:attr ...
#  'Control Framework Messages - The usage of CONTROL, response, and REPORT messages, as defined in [i11], by each Control Package defined in MSML is different and described separately in the following sections. - 7. MSML Core Package - 8.3. <createconference> - 8.4. <modifyconference> - 8.5. <destroyconference> - 8.6. <audiomix> - 8.7. <videolayout> - 8.7.3.1. Voice Activated Switching ("vas") - 8.9. <modifystream> - 8.11. <monitor> - 8.12.1. Audio Stream Properties - 9.6.1. <dialogstart> - 9.6.2. <dialogend> - 9.6.5. <disconnect> - 9.7.2.1. <dtmfgenexit> - Child Elements: - <tone1> - 9.7.3.3. <tonegenexit> - 9.8. MSML Dialog Group Package - 9.10. MSML Dialog Speech Package - 9.10.1.5. <speechexit> - 9.11.1. <faxdetect> - 9.12.1.5. <faxnegotiate> - 9.12.1.6. <faxpagedone> - 9.12.1.7. <faxobjectdone> - 9.12.1.8. <faxopcomplete> - 9.12.1.9. <faxpollstarted> - 10.1. MSML Audit Core Package - 10.2.1. State Parameters - 10.2.2.1. confconfig - 10.2.2.2. confconfig.audiomix - 10.2.2.3. confconfig.audiomix.asn - 10.2.2.4. confconfig.audiomix.n-loudest - 10.2.2.5. confconfig.videolayout - 10.2.2.6. confconfig.videolayout.root - 10.2.2.7. confconfig.videolayout.selector - 10.3.1. State Parameters - 10.3.2.1. sipdialog - 11. Response Codes - 12.2. Example of a Sidebar Audio Conference - 12.4. Example of Modifying Video Layout - 13.1. Announcement - 13.2. Voice Mail Retrieval - 13.3. Play and Record - 13.4. Speech Recognition - 13.5. Play and Collect - The following implements the same functionality, as described above, using the MSML Dialog Base Package, using the <collect> composite mechanism for the play and collect operation. - 13.6. User Controlled Gain - 14.1. Audit All Conferences - 14.2. Audit Conference Dialogs - 14.3. Audit Conference Streams - 14.4. Audit All Connections - 14.5. Audit Connection Dialogs - 14.6. Audit Connection Streams - 14.7. Audit Connection with Selective States - This example describes an audit of a specific connection, querying associated SIP dialog ID and SDP info. - 16. XML Schema - <xs:schema xmlns:xs="http://www.w3.org/2001/XMLSchema" elementFormDefault="qualified" attributeFormDefault="unqualified"> <xs:include schemaLocation="msml-core-datatypes.xsd"/> <xs:include schemaLocation="msml-conf-core-datatypes.xsd"/> <xs:include schemaLocation="msml-dialog-core-datatypes.xsd"/> <xs:include schemaLocation="msml-dialog-base-datatypes.xsd"/> <xs:include schemaLocation="msml-dialog-transform-datatypes.xsd"/> <xs:include schemaLocation="msml-dialog-group-datatypes.xsd"/> <xs:include schemaLocation="msml-dialog-speech-datatypes.xsd"/> <xs:include schemaLocation="msml-dialog-fax-detect-datatypes.xsd"/> <xs:include schemaLocation="msml-dialog-fax-sendrecv- <xs:include schemaLocation="msml-audit-core-datatypes.xsd"/> - 16.1.1. msml-core.xsd - 16.1.2. msml-core-datatypes.xsd - <xs:schema xmlns:xs="http://www.w3.org/2001/XMLSchema" elementFormDefault="qualified" attributeFormDefault="unqualified"> <xs:include schemaLocation="msml-core-datatypes.xsd"/> <xs:group name="momlRequest"> <xs:choice> <xs:group ref="executeType"/>. <xs:attribute name="audiosamplesize" type="xs:positiveInteger" <xs:attribute name="profile" use="optional"> <xs:simpleType> <xs:restriction base="xs:string"/> </xs:simpleType> </xs:attribute> <xs:attribute name="level" use="optional"> <xs:simpleType> <xs:restriction base="xs:string"/> </xs:simpleType> </xs:attribute> <xs:attribute name="imagewidth" type="xs:positiveInteger" <xs:attribute name="imageheight" type="xs:positiveInteger" <xs:attribute name="maxbitrate" type="xs:positiveInteger" <xs:attribute name="framerate" type="xs:positiveInteger" <xs:attribute name="maxtime" type="posDuration.datatype" <xs:attribute name="initial" use="optional" default="create"> <xs:simpleType> <xs:restriction base="xs:string"> <xs:enumeration value="create"/> <xs:enumeration value="suspend"/> </xs:restriction> </xs:simpleType> </xs:attribute> <xs:attribute name="prespeech" type="posDuration.datatype" use="optional"  ...
#  ...]
