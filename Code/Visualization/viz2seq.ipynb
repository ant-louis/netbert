# %% [markdown]
# # Visualizing the input data

# %% [markdown]
# ### Checking the size of the input data

# %%
import os

words = []
file_path = '/raid/antoloui/Master-thesis/Data/Cleaned/train.raw'
with open(file_path) as myfile:
    for count_sent, line in enumerate(myfile):
        words.extend(line.split())
    vocab = set(words)
    print("Total number of sentences: {}".format(count_sent))
    print("Total number of words: {}".format(len(words)))
    print("Size of the vocabulary (unique words): {}".format(len(vocab)))
    print("Size of the file: {:2f} GB".format(os.path.getsize(file_path)/(1024*1024*1024)))
# Out:
# Total number of sentences: 145881887
# Total number of words: 3104401545
# Size of the vocabulary (unique words): 4616807
# Size of the file: 19.057284 GB

# %% [markdown]
# ### Showing the dataset statistics

# %%
import vizseq

file_path = '/raid/antoloui/Master-thesis/Data/Cleaned/train.raw'
vizseq.view_stats(file_path, None) #sentence length distribution
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.2.1/css/bootstrap.min.css"
#           integrity="sha384-GJzZqFGwb1QTTN6wy59ffF1BuGJpLSa9DkKMp0DgiMDm4iYMj70gZWKYbI706tWS" crossorigin="anonymous">
#
#     <style>
#         body {
#             padding-top: 60px; /* 60px to make the container go all the way to the bottom of the topbar */
#         }
#     </style>
# </head>
#
# <body>
#
# <div class="container-fluid">
#     <div class="row">
#         <table class="table table-hover table-bordered">
#             <thead class="thead-light">
#             <tr>
#                 <th scope="col"></th>
#                 <th scope="col">Type</th>
#                 <th scope="col">Examples</th>
#                 <th scope="col">Tokens / Frames</th>
#                 <th scope="col">Chars / Duration (ms)</th>
#             </tr>
#             </thead>
#             <tbody id="statsTable">
#
#             <tr>
#                 <th scope="row">Source 0</th>
#                 <td>Text</td>
#                 <td>153,475,762</td>
#                 <td>3,338,668,340</td>
#                 <td>21,687,116,771</td>
#             </tr>
#
#
#             </tbody>
#         </table>
#     </div>
# </div>
#
# <script src="https://code.jquery.com/jquery-3.3.1.slim.min.js"
#         integrity="sha384-q8i/X+965DzO0rT7abK41JStQIAqVgRVzpbzo5smXKp4YfRvH+8abtTE1Pi6jizo" crossorigin="anonymous">
# </script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.14.6/umd/popper.min.js"
#         integrity="sha384-wHAiFfRlMFy6i5SRaxvfOCifBUQy1xHdJ/yoi7FRNXMRBu5WHdZYu1hA6ZOblgut" crossorigin="anonymous">
# </script>
# <script src="https://stackpath.bootstrapcdn.com/bootstrap/4.2.1/js/bootstrap.min.js"
#         integrity="sha384-B0UglyR+jN6CkvvICOB2joaf5I4l3gm9GU6Hc1og6Ls7i6U/mkkaduKaBhlAXv9k" crossorigin="anonymous">
# </script>
#
# </body>
# </html>

# %% [markdown]
# ### Showing the n-grams in the input data

# %%
import vizseq

file_path = '/raid/antoloui/Master-thesis/Data/Cleaned/train.raw'
vizseq.view_n_grams(file_path, k=100) ## k=number of n-grams to be shown (Default to 64)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.2.1/css/bootstrap.min.css"
#           integrity="sha384-GJzZqFGwb1QTTN6wy59ffF1BuGJpLSa9DkKMp0DgiMDm4iYMj70gZWKYbI706tWS" crossorigin="anonymous">
#     <script src="https://kit.fontawesome.com/3c563f9647.js"></script>
#
#     <style>
#         body {
#             padding-top: 60px; /* 60px to make the container go all the way to the bottom of the topbar */
#         }
#     </style>
# </head>
#
# <body>
#
#
# <div class="container">
#     <div class="row">
#
#         <div class="col">
#             <table class="table table-hover table-sm table-bordered text-center">
#                 <thead class="thead-light">
#                 <tr><th scope="col">1-gram</th><th scope="col">Count</th></tr>
#                 </thead>
#                 <tbody>
#
#                 <tr><td>the</td><td>225306739</td></tr>
#
#                 <tr><td>to</td><td>81860777</td></tr>
#
#                 <tr><td>and</td><td>57218627</td></tr>
#
#                 <tr><td>a</td><td>55062410</td></tr>
#
#                 <tr><td>of</td><td>54612519</td></tr>
#
#                 <tr><td>for</td><td>43653626</td></tr>
#
#                 <tr><td>is</td><td>43059962</td></tr>
#
#                 <tr><td>in</td><td>40726862</td></tr>
#
#                 <tr><td>or</td><td>31764717</td></tr>
#
#                 <tr><td>you</td><td>29032495</td></tr>
#
#                 <tr><td>this</td><td>28159434</td></tr>
#
#                 <tr><td>on</td><td>25267323</td></tr>
#
#                 <tr><td>that</td><td>23739849</td></tr>
#
#                 <tr><td>cisco</td><td>22893283</td></tr>
#
#                 <tr><td>command</td><td>16571575</td></tr>
#
#                 <tr><td>with</td><td>16220491</td></tr>
#
#                 <tr><td>configuration</td><td>16128181</td></tr>
#
#                 <tr><td>if</td><td>15760476</td></tr>
#
#                 <tr><td>are</td><td>15669780</td></tr>
#
#                 <tr><td>not</td><td>15375561</td></tr>
#
#                 <tr><td>an</td><td>14956553</td></tr>
#
#                 <tr><td>be</td><td>14657772</td></tr>
#
#                 <tr><td>by</td><td>13767164</td></tr>
#
#                 <tr><td>from</td><td>13176981</td></tr>
#
#                 <tr><td>as</td><td>13127138</td></tr>
#
#                 <tr><td>can</td><td>12027191</td></tr>
#
#                 <tr><td>ip</td><td>11866885</td></tr>
#
#                 <tr><td>use</td><td>11851335</td></tr>
#
#                 <tr><td>step</td><td>10416913</td></tr>
#
#                 <tr><td>any</td><td>9897921</td></tr>
#
#                 <tr><td>interface</td><td>9733805</td></tr>
#
#                 <tr><td>all</td><td>9363377</td></tr>
#
#                 <tr><td>no</td><td>9069913</td></tr>
#
#                 <tr><td></td><td>8630159</td></tr>
#
#                 <tr><td>when</td><td>8307209</td></tr>
#
#                 <tr><td>it</td><td>8193107</td></tr>
#
#                 <tr><td>software</td><td>7891592</td></tr>
#
#                 <tr><td>release</td><td>7730524</td></tr>
#
#                 <tr><td>following</td><td>7622776</td></tr>
#
#                 <tr><td>configure</td><td>7602816</td></tr>
#
#                 <tr><td>information</td><td>7486541</td></tr>
#
#                 <tr><td>•</td><td>7463980</td></tr>
#
#                 <tr><td>show</td><td>7435300</td></tr>
#
#                 <tr><td>your</td><td>7358342</td></tr>
#
#                 <tr><td>1</td><td>7213765</td></tr>
#
#                 <tr><td>port</td><td>7213206</td></tr>
#
#                 <tr><td>number</td><td>7064525</td></tr>
#
#                 <tr><td>access</td><td>6987995</td></tr>
#
#                 <tr><td>address</td><td>6818647</td></tr>
#
#                 <tr><td>server</td><td>6625163</td></tr>
#
#                 <tr><td>system</td><td>6400705</td></tr>
#
#                 <tr><td>service</td><td>6191023</td></tr>
#
#                 <tr><td>|</td><td>6041235</td></tr>
#
#                 <tr><td>default</td><td>6026732</td></tr>
#
#                 <tr><td>must</td><td>6004925</td></tr>
#
#                 <tr><td>using</td><td>5961831</td></tr>
#
#                 <tr><td>network</td><td>5959356</td></tr>
#
#                 <tr><td>user</td><td>5782060</td></tr>
#
#                 <tr><td>source</td><td>5778974</td></tr>
#
#                 <tr><td>which</td><td>5759648</td></tr>
#
#                 <tr><td>license</td><td>5705004</td></tr>
#
#                 <tr><td>other</td><td>5603704</td></tr>
#
#                 <tr><td>switch</td><td>5573949</td></tr>
#
#                 <tr><td>used</td><td>5549931</td></tr>
#
#                 <tr><td>name</td><td>5372819</td></tr>
#
#                 <tr><td>2</td><td>5342512</td></tr>
#
#                 <tr><td>at</td><td>5172353</td></tr>
#
#                 <tr><td>description</td><td>4996543</td></tr>
#
#                 <tr><td>configuring</td><td>4989216</td></tr>
#
#                 <tr><td>ios</td><td>4869555</td></tr>
#
#                 <tr><td>only</td><td>4745855</td></tr>
#
#                 <tr><td>click</td><td>4720490</td></tr>
#
#                 <tr><td>enter</td><td>4591870</td></tr>
#
#                 <tr><td>will</td><td>4524616</td></tr>
#
#                 <tr><td>support</td><td>4511219</td></tr>
#
#                 <tr><td>have</td><td>4485155</td></tr>
#
#                 <tr><td>these</td><td>4419919</td></tr>
#
#                 <tr><td>group</td><td>4376277</td></tr>
#
#                 <tr><td>set</td><td>4373972</td></tr>
#
#                 <tr><td>device</td><td>4358399</td></tr>
#
#                 <tr><td>page</td><td>4296587</td></tr>
#
#                 <tr><td>work</td><td>4281924</td></tr>
#
#                 <tr><td>version</td><td>4274406</td></tr>
#
#                 <tr><td>see</td><td>4263820</td></tr>
#
#                 <tr><td>commands</td><td>4260511</td></tr>
#
#                 <tr><td>enable</td><td>4223566</td></tr>
#
#                 <tr><td>may</td><td>4157726</td></tr>
#
#                 <tr><td>each</td><td>4154681</td></tr>
#
#                 <tr><td>one</td><td>4121169</td></tr>
#
#                 <tr><td>note</td><td>4105160</td></tr>
#
#                 <tr><td>under</td><td>3976980</td></tr>
#
#                 <tr><td>vlan</td><td>3966817</td></tr>
#
#                 <tr><td>file</td><td>3966802</td></tr>
#
#                 <tr><td>message</td><td>3961238</td></tr>
#
#                 <tr><td>&gt;</td><td>3939721</td></tr>
#
#                 <tr><td>data</td><td>3926786</td></tr>
#
#                 <tr><td>such</td><td>3901776</td></tr>
#
#                 <tr><td>mode</td><td>3872020</td></tr>
